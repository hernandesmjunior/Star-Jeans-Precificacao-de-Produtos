# %% [markdown]
# # Extração de Dados em HTML
#
# ID, product_name, product_type, product_color, composition, price

# %%
import requests
import pandas as pd
import numpy as np
import re
from datetime import datetime
from bs4 import BeautifulSoup

# %%
url = 'https://www2.hm.com/en_us/men/products/jeans.html'

headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/50.0.2661.102 Safari/537.36'}

page = requests.get(url, headers=headers)

# %%
soup = BeautifulSoup(page.text, 'html.parser')

# %%
products = soup.find('ul', class_='products-listing small')

# %%
product_list = products.find_all('article', class_='hm-product-item')
product_list
# Out:
# [<article class="hm-product-item" data-articlecode="0985159001" data-category="men_jeans_skinny" data-energy-interval="" data-pre-access-end-date="" data-pre-access-groups="" data-pre-access-start-date="" onclick="setOsaParameters(utag_data.category_id,'SMALL','0985159001'); setNotificationTicket('Oy9wbHAvcHJvZHVjdC1saXN0LXdpdGgtY291bnQvcHJvZHVjdC1saXN0OyM7cHJvZHVjdF9rZXk7MDk4NTE1OV9ncm91cF8wMDFfZW5fdXM7MDk4NTE1OTAwMV9lbl91cztPQkpFQ1RJVkUkO05PTkU6Tk9ORTs3NTs','0985159001');">
#  <div class="image-container">
#  <a class="item-link" href="/en_us/productpage.0985159001.html" title="Skinny Jeans">
#  <img alt="Skinny JeansModel" class="item-image" data-altimage="//lp2.hm.com/hmgoepprod?set=source[/28/f0/28f0649eb24faedfb7baf756d9cc7b86f31e37de.jpg],origin[dam],category[],type[DESCRIPTIVESTILLLIFE],res[m],hmver[2]&amp;call=url[file:/product/style]" data-alttext="Skinny Jeans" data-src="//lp2.hm.com/hmgoepprod?set=source[/0a/29/0a29e9a927238a518e8d0a4194bbd1d48a3eff2a.jpg],origin[dam],category[],type[LOOKBOOK],res[m],hmver[1]&amp;call=url[file:/product/style]" src="//lp2.hm.com/hmgoepprod?set=source[/0a/29/0a29e9a927238a518e8d0a4194bbd1d48a3eff2a.jpg],origin[dam],category[],type[LOOKBOOK],res[m],hmver[1]&amp;call=url[file:/product/style]"/>
#  <div class="item-buttons">
#  <button class="favorite icon-favorites js-favorite" data-not-saved-text="SAVE AS FAVORITE" data-saved-text="SAVED AS FAVORITE" data-tracking-json-template="utagFavorite" data-tracking-params="Favourites|0985159001|Skinny Jeans|MEN_SHOPBYPRODUCT : JEANS_JEANS : VIEWALL_VIEW_ALL" data-tracking-type="event">
#  				SAVE AS FAVORITE</button>
#  </div></a>
#  </div><div class="item-details">
#  <div class="marketing-marker marker-environment" style="">
#  		Conscious </div>
#  <h3 class="item-heading">
#  <a class="link" href="/en_us/productpage.0985159001.html">Skinny Jeans</a>
#  </h3><strong class="item-price">
#  <span class="price regular">$ 19.99</span>
#  </strong><ul class="list-swatches" data-swatches-total="5">
#  <li class="item"><a class="swatch" href="/en_us/productpage.0985159001.html" style="background-color: #272628" title="Black">
#  				Black</a></li>
#  <li class="item"><a class="swatch" href="/en_us/productpage.0985159002.html" style="background-color: #6089C2" title="Denim blue">
#  				Denim blue</a></li>
#  <li class="item"><a class="swatch" href="/en_us/productpage.0985159003.html" style="background-color: #666B75" title="Dark gray">
#  				Dark gray</a></li>
#  <li class="item"><a class="swatch" href="/en_us/productpage.0985159004.html" style="background-color: #8898AC" title="Light denim blue">
#  				Light denim blue</a></li>
#  </ul></div></article>,
#  <article class="hm-product-item" data-articlecode="0985197001" data-category="men_jeans_slim" data-energy-interval="" data-pre-access-end-date="" data-pre-access-groups="" data-pre-access-start-date="" onclick="setOsaParameters(utag_data.category_id,'SMALL','0985197001'); setNotificationTicket('Oy9wbHAvcHJvZHVjdC1saXN0LXdpdGgtY291bnQvcHJvZHVjdC1saXN0OyM7cHJvZHVjdF9rZXk7MDk4NTE5N19ncm91cF8wMDFfZW5fdXM7MDk4NTE5NzAwMV9lbl91cztPQkpFQ1RJVkUkO05PTkU6Tk9ORTs3NTs','0985197001');">
#  <div class="image-container">
#  <a class="item-link" href="/en_us/productpage.0985197001.html" title="Slim Jeans">
#  <img alt="Slim JeansModel" class="item-image" data-altimage="//lp2.hm.com/hmgoepprod?set=source[/b6/26/b626e8a76cc287928788b5edc8d1fa2679440a88.jpg],origin[dam],category[],type[DESCRIPTIVESTILLLIFE],res[m],hmver[2]&amp;call=url[file:/product/style]" data-alttext="Slim Jeans" data-src="//lp2.hm.com/hmgoepprod?set=source[/6a/6a/6a6adf7dede242a98b194fee7cc8f60e4737ae0a.jpg],origin[dam],category[],type[LOOKBOOK],res[m],hmver[1]&amp;call=url[file:/product/style]" src="//lp2.hm.com/hmgoepprod?set=source[/6a/6a/6a6adf7dede242a98b194fee7cc8f60e4737ae0a.jpg],origin[dam],category[],type[LOOKBOOK],res[m],hmver[1]&amp;call=url[file:/product/style]"/>
#  <div class="item-buttons">
#  <button class="favorite icon-favorites js-favorite" data-not-saved-text="SAVE AS FAVORITE" data-saved-text="SAVED AS FAVORITE" data-tracking-json-template="utagFavorite" data-tracking-params="Favourites|0985197001|Slim Jeans|MEN_SHOPBYPRODUCT : JEANS_JEANS : VIEWALL_VIEW_ALL" data-tracking-type="event">
#  				SAVE AS FAVORITE</button>
#  </div></a>
#  </div><div class="item-details">
#  <div class="marketing-marker marker-environment" style="">
#  		Conscious </div>
#  <h3 class="item-heading">
#  <a class="link" href="/en_us/productpage.0985197001.html">Slim Jeans</a>
#  </h3><strong class="item-price">
#  <span class="price regular">$ 19.99</span>
#  </strong><ul class="list-swatches" data-swatches-total="4">
#  <li class="item"><a class="swatch" href="/en_us/productpage.0985197001.html" style="background-color: #272628" title="Black">
#  				Black</a></li>
#  <li class="item"><a class="swatch" href="/en_us/productpage.0985197002.html" style="background-color: #2F323B" title="Midnight blue">
#  				Midnight blue</a></li>
#  <li class="item"><a class="swatch" href="/en_us/productpage.0985197003.html" style="background-color: #79829D" title="Denim blue">
#  				Denim blue</a></li>
#  <li class="item"><a class="swatch" href="/en_us/productpage.0985197006.html" style="background-color: #8898AC" title="Light denim blue">
#  				Light denim blue</a></li>
#  </ul></div></article>,
#  <article class="hm-product-item" data-articlecode="0690449022" data-category="men_jeans_ripped" data-energy-interval="" data-pre-access-end-date="" data-pre-access-groups="" data-pre-access-start-date="" onclick="setOsaParameters(utag_data.category_id,'SMALL','0690449022'); setNotificationTicket('Oy9wbHAvcHJvZHVjdC1saXN0LXdpdGgtY291bnQvcHJvZHVjdC1saXN0OyM7cHJvZHVjdF9rZXk7MDY5MDQ0OV9ncm91cF8wMjJfZW5fdXM7MDY5MDQ0OTAyMl9lbl91cztPQkpFQ1RJVkUkO05PTkU6Tk9ORTs3NTs','0690449022');">
#  <div class="image-container">
#  <a class="item-link" href="/en_us/productpage.0690449022.html" title="Skinny Jeans">
#  <img alt="Skinny JeansModel" class="item-image" data-altimage="//lp2.hm.com/hmgoepprod?set=source[/dc/be/dcbec7b58345a0f1defb8ea12a7b83724e0ea8d1.jpg],origin[dam],category[men_jeans_skinny],type[DESCRIPTIVESTILLLIFE],res[m],hmver[2]&amp;call=url[file:/product/style]" data-alttext="Skinny Jeans" data-src="//lp2.hm.com/hmgoepprod?set=source[/50/9e/509ec879555bdc8f312bab8b1215d64a2d242459.jpg],origin[dam],category[men_jeans_skinny],type[LOOKBOOK],res[m],hmver[1]&amp;call=url[file:/product/style]" src="//lp2.hm.com/hmgoepprod?set=source[/50/9e/509ec879555bdc8f312bab8b1215d64a2d242459.jpg],origin[dam],category[men_jeans_skinny],type[LOOKBOOK],res[m],hmver[1]&amp;call=url[file:/product/style]"/>
#  <div class="item-buttons">
#  <button class="favorite icon-favorites js-favorite" data-not-saved-text="SAVE AS FAVORITE" data-saved-text="SAVED AS FAVORITE" data-tracking-json-template="utagFavorite" data-tracking-params="Favourites|0690449022|Skinny Jeans|MEN_SHOPBYPRODUCT : JEANS_JEANS : VIEWALL_VIEW_ALL" data-tracking-type="event">
#  				SAVE AS FAVORITE</button>
#  </div></a>
#  </div><div class="item-details">
#  <h3 class="item-heading">
#  <a class="link" href="/en_us/productpage.0690449022.html">Skinny Jeans</a>
#  </h3><strong class="item-price">
#  <span class="price regular">$ 39.99</span>
#  </strong><ul class="list-swatches" data-swatches-total="1">
#  <li class="item"><a class="swatch" href="/en_us/productpage.0690449022.html" style="background-color: #363638" title="Black/trashed">
#  				Black/trashed</a></li>
#  </ul></div></article>,
#  <article class="hm-product-item" data-articlecode="0985197002" data-category="men_jeans_slim" data-energy-interval="" data-pre-access-end-date="" data-pre-access-groups="" data-pre-access-start-date="" onclick="setOsaParameters(utag_data.category_id,'SMALL','0985197002'); setNotificationTicket('Oy9wbHAvcHJvZHVjdC1saXN0LXdpdGgtY291bnQvcHJvZHVjdC1saXN0OyM7cHJvZHVjdF9rZXk7MDk4NTE5N19ncm91cF8wMDJfZW5fdXM7MDk4NTE5NzAwMl9lbl91cztPQkpFQ1RJVkUkO05PTkU6Tk9ORTs3NTs','0985197002');">
#  <div class="image-container">
#  <a class="item-link" href="/en_us/productpage.0985197002.html" title="Slim Jeans">
#  <img alt="Slim JeansModel" class="item-image" data-altimage="//lp2.hm.com/hmgoepprod?set=source[/2e/8a/2e8a0079ede7825b7747aa2a7a2db8fe337150d2.jpg],origin[dam],category[men_jeans_slim],type[DESCRIPTIVESTILLLIFE],res[m],hmver[2]&amp;call=url[file:/product/style]" data-alttext="Slim Jeans" data-src="//lp2.hm.com/hmgoepprod?set=source[/de/3d/de3d7ed0f397d4070b81ba7a4382a790e59dd077.jpg],origin[dam],category[],type[LOOKBOOK],res[m],hmver[1]&amp;call=url[file:/product/style]" src="//lp2.hm.com/hmgoepprod?set=source[/de/3d/de3d7ed0f397d4070b81ba7a4382a790e59dd077.jpg],origin[dam],category[],type[LOOKBOOK],res[m],hmver[1]&amp;call=url[file:/product/style]"/>
#  <div class="item-buttons">
#  <button class="favorite icon-favorites js-favorite" data-not-saved-text="SAVE AS FAVORITE" data-saved-text="SAVED AS FAVORITE" data-tracking-json-template="utagFavorite" data-tracking-params="Favourites|0985197002|Slim Jeans|MEN_SHOPBYPRODUCT : JEANS_JEANS : VIEWALL_VIEW_ALL" data-tracking-type="event">
#  				SAVE AS FAVORITE</button>
#  </div></a>
#  </div><div class="item-details">
#  <div class="marketing-marker marker-environment" style="">
#  		Conscious </div>
#  <h3 class="item-heading">
#  <a class="link" href="/en_us/productpage.0985197002.html">Slim Jeans</a>
#  </h3><strong class="item-price">
#  <span class="price regular">$ 19.99</span>
#  </strong><ul class="list-swatches" data-swatches-total="4">
#  <li class="item"><a class="swatch" href="/en_us/productpage.0985197002.html" style="background-color: #2F323B" title="Midnight blue">
#  				Midnight blue</a></li>
#  <li class="item"><a class="swatch" href="/en_us/productpage.0985197001.html" style="background-color: #272628" title="Black">
#  				Black</a></li>
#  <li class="item"><a class="swatch" href="/en_us/productpage.0985197003.html" style="background-color: #79829D" title="Denim blue">
#  				Denim blue</a></li>
#  <li class="item"><a class="swatch" href="/en_us/productpage.0985197006.html" style="background-color: #8898AC" title="Light denim blue">
#  				Light denim blue</a></li>
#  </ul></div></article>,
#  <article class="hm-product-item" data-articlecode="0985159003" data-category="men_jeans_skinny" data-energy-interval="" data-pre-access-end-date="" data-pre-access-groups="" data-pre-access-start-date="" onclick="setOsaParameters(utag_data.category_id,'SMALL','0985159003'); setNotificationTicket('Oy9wbHAvcHJvZHVjdC1saXN0LXdpdGgtY291bnQvcHJvZHVjdC1saXN0OyM7cHJvZHVjdF9rZXk7MDk4NTE1OV9ncm91cF8wMDNfZW5fdXM7MDk4NTE1OTAwM19lbl91cztPQkpFQ1RJVkUkO05PTkU6Tk9ORTs3NTs','0985159003');">
#  <div class="image-container">
#  <a class="item-link" href="/en_us/productpage.0985159003.html" title="Skinny Jeans">
#  <img alt="Skinny JeansModel" class="item-image" data-altimage="//lp2.hm.com/hmgoepprod?set=source[/3b/96/3b9675cd1f97ce69d2787406457e984944b77c7c.jpg],origin[dam],category[],type[DESCRIPTIVESTILLLIFE],res[m],hmver[2]&amp;call=url[file:/product/style]" data-alttext="Skinny Jeans" data-src="//lp2.hm.com/hmgoepprod?set=source[/77/15/7715c86a9655ccd67c2f5ce927b948ac44d58045.jpg],origin[dam],category[],type[LOOKBOOK],res[m],hmver[1]&amp;call=url[file:/product/style]"/>
#  <div class="item-buttons">
#  <button class="favorite icon-favorites js-favorite" data-not-saved-text="SAVE AS FAVORITE" data-saved-text="SAVED AS FAVORITE" data-tracking-json-template="utagFavorite" data-tracking-params="Favourites|0985159003|Skinny Jeans|MEN_SHOPBYPRODUCT : JEANS_JEANS : VIEWALL_VIEW_ALL" data-tracking-type="event">
#  				SAVE AS FAVORITE</button>
#  </div></a>
#  </div><div class="item-details">
#  <div class="marketing-marker marker-environment" style="">
#  		Conscious </div>
#  <h3 class="item-heading">
#  <a class="link" href="/en_us/productpage.0985159003.html">Skinny Jeans</a>
#  </h3><strong class="item-price">
#  <span class="price regular">$ 19.99</span>
#  </strong><ul class="list-swatches" data-swatches-total="5">
#  <li class="item"><a class="swatch" href="/en_us/productpage.0985159003.html" style="background-color: #666B75" title="Dark gray">
#  				Dark gray</a></li>
#  <li class="item"><a class="swatch" href="/en_us/productpage.0985159001.html" style="background-color: #272628" title="Black">
#  				Black</a></li>
#  <li class="item"><a class="swatch" href="/en_us/productpage.0985159002.html" style="background-color: #6089C2" title="Denim blue">
#  				Denim blue</a></li>
#  <li class="item"><a class="swatch" href="/en_us/productpage.0985159004.html" style="background-color: #8898AC" title="Light denim blue">
#  				Light denim blue</a></li>
#  </ul></div></article>,
#  <article class="hm-product-item" data-articlecode="0427159006" data-category="men_jeans_ripped" data-energy-interval="" data-pre-access-end-date="" data-pre-access-groups="" data-pre-access-start-date="" onclick="setOsaParameters(utag_data.category_id,'SMALL','0427159006'); setNotificationTicket('Oy9wbHAvcHJvZHVjdC1saXN0LXdpdGgtY291bnQvcHJvZHVjdC1saXN0OyM7cHJvZHVjdF9rZXk7MDQyNzE1OV9ncm91cF8wMDZfZW5fdXM7MDQyNzE1OTAwNl9lbl91cztPQkpFQ1RJVkUkO05PTkU6Tk9ORTs3NTs','0427159006');">
#  <div class="image-container">
#  <a class="item-link" href="/en_us/productpage.0427159006.html" title="Trashed Skinny Jeans">
#  <img alt="Trashed Skinny JeansModel" class="item-image" data-altimage="//lp2.hm.com/hmgoepprod?set=source[/66/23/662340f98a04b05c788b4fa3f3e340db29f9688b.jpg],origin[dam],category[men_jeans_skinny],type[DESCRIPTIVESTILLLIFE],res[m],hmver[2]&amp;call=url[file:/product/style]" data-alttext="Trashed Skinny Jeans" data-src="//lp2.hm.com/hmgoepprod?set=source[/f3/2b/f32b19374db44d8aeb560c623b2b5794566dc8d5.jpg],origin[dam],category[men_jeans_skinny],type[LOOKBOOK],res[m],hmver[1]&amp;call=url[file:/product/style]"/>
#  <div class="item-buttons">
#  <button class="favorite icon-favorites js-favorite" data-not-saved-text="SAVE AS FAVORITE" data-saved-text="SAVED AS FAVORITE" data-tracking-json-template="utagFavorite" data-tracking-params="Favourites|0427159006|Trashed Skinny Jeans|MEN_SHOPBYPRODUCT : JEANS_JEANS : VIEWALL_VIEW_ALL" data-tracking-type="event">
#  				SAVE AS FAVORITE</button>
#  </div></a>
#  </div><div class="item-details">
#  <div class="marketing-marker marker-environment" style="">
#  		Conscious </div>
#  <h3 class="item-heading">
#  <a class="link" href="/en_us/productpage.0427159006.html">Trashed Skinny Jeans</a>
#  </h3><strong class="item-price">
#  <span class="price regular">$ 39.99</span>
#  </strong><ul class="list-swatches" data-swatches-total="1">
#  <li class="item"><a class="swatch" href="/en_us/productpage.0427159006.html" style="background-color: #8898AC" title="Light denim blue">
#  				Light denim blue</a></li>
#  </ul></div></article>,
#  <article class="hm-product-item" data-articlecode="0985197003" data-category="men_jeans_slim" data-energy-interval="" data-pre-access-end-date="" data-pre-access-groups="" data-pre-access-start-date="" onclick="setOsaParameters(utag_data.category_id,'SMALL','0985197003'); setNotificationTicket('Oy9wbHAvcHJvZHVjdC1saXN0LXdpdGgtY291bnQvcHJvZHVjdC1saXN0OyM7cHJvZHVjdF9rZXk7MDk4NTE5N19ncm91cF8wMDNfZW5fdXM7MDk4NTE5NzAwM19lbl91cztPQkpFQ1RJVkUkO05PTkU6Tk9ORTs3NTs','0985197003');">
#  <div class="image-container">
#  <a class="item-link" href="/en_us/productpage.0985197003.html" title="Slim Jeans">
#  <img alt="Slim JeansModel" class="item-image" data-altimage="//lp2.hm.com/hmgoepprod?set=source[/3b/51/3b51c786937a2f21b1310754bf49b9c1bfca28da.jpg],origin[dam],category[],type[DESCRIPTIVESTILLLIFE],res[m],hmver[2]&amp;call=url[file:/product/style]" data-alttext="Slim Jeans" data-src="//lp2.hm.com/hmgoepprod?set=source[/e0/42/e042fe4b2cfa46be8a80e633028d86b509692a9f.jpg],origin[dam],category[],type[LOOKBOOK],res[m],hmver[1]&amp;call=url[file:/product/style]"/>
#  <div class="item-buttons">
#  <button class="favorite icon-favorites js-favorite" data-not-saved-text="SAVE AS FAVORITE" data-saved-text="SAVED AS FAVORITE" data-tracking-json-template="utagFavorite" data-tracking-params="Favourites|0985197003|Slim Jeans|MEN_SHOPBYPRODUCT : JEANS_JEANS : VIEWALL_VIEW_ALL" data-tracking-type="event">
#  				SAVE AS FAVORITE</button>
#  </div></a>
#  </div><div class="item-details">
#  <div class="marketing-marker marker-environment" style="">
#  		Conscious </div>
#  <h3 class="item-heading">
#  <a class="link" href="/en_us/productpage.0985197003.html">Slim Jeans</a>
#  </h3><strong class="item-price">
#  <span class="price regular">$ 19.99</span>
#  </strong><ul class="list-swatches" data-swatches-total="4">
#  <li class="item"><a class="swatch" href="/en_us/productpage.0985197003.html" style="background-color: #79829D" title="Denim blue">
#  				Denim blue</a></li>
#  <li class="item"><a class="swatch" href="/en_us/productpage.0985197001.html" style="background-color: #272628" title="Black">
#  				Black</a></li>
#  <li class="item"><a class="swatch" href="/en_us/productpage.0985197002.html" style="background-color: #2F323B" title="Midnight blue">
#  				Midnight blue</a></li>
#  <li class="item"><a class="swatch" href="/en_us/productpage.0985197006.html" style="background-color: #8898AC" title="Light denim blue">
#  				Light denim blue</a></li>
#  </ul></div></article>,
#  <article class="hm-product-item" data-articlecode="0971061001" data-category="" data-energy-interval="" data-pre-access-end-date="" data-pre-access-groups="" data-pre-access-start-date="" onclick="setOsaParameters(utag_data.category_id,'SMALL','0971061001'); setNotificationTicket('Oy9wbHAvcHJvZHVjdC1saXN0LXdpdGgtY291bnQvcHJvZHVjdC1saXN0OyM7cHJvZHVjdF9rZXk7MDk3MTA2MV9ncm91cF8wMDFfZW5fdXM7MDk3MTA2MTAwMV9lbl91cztPQkpFQ1RJVkUkO05PTkU6Tk9ORTs3NTs','0971061001');">
#  <div class="image-container">
#  <a class="item-link" href="/en_us/productpage.0971061001.html" title="Slim Tapered Cropped Jeans">
#  <img alt="Slim Tapered Cropped JeansModel" class="item-image" data-altimage="//lp2.hm.com/hmgoepprod?set=source[/f4/80/f4805a63f059cb8fd649bc5937dceeff3b3ed356.jpg],origin[dam],category[],type[DESCRIPTIVESTILLLIFE],res[m],hmver[2]&amp;call=url[file:/product/style]" data-alttext="Slim Tapered Cropped Jeans" data-src="//lp2.hm.com/hmgoepprod?set=source[/20/3d/203d3173a6097fc2b0edbcfb2370874e924de8ba.jpg],origin[dam],category[],type[LOOKBOOK],res[m],hmver[1]&amp;call=url[file:/product/style]"/>
#  <div class="item-buttons">
#  <button class="favorite icon-favorites js-favorite" data-not-saved-text="SAVE AS FAVORITE" data-saved-text="SAVED AS FAVORITE" data-tracking-json-template="utagFavorite" data-tracking-params="Favourites|0971061001|Slim Tapered Cropped Jeans|MEN_SHOPBYPRODUCT : JEANS_JEANS : VIEWALL_VIEW_ALL" data-tracking-type="event">
#  				SAVE AS FAVORITE</button>
#  </div></a>
#  </div><div class="item-details">
#  <div class="marketing-marker marker-environment" style="">
#  		Conscious </div>
#  <h3 class="item-heading">
#  <a class="link" href="/en_us/productpage.0971061001.html">Slim Tapered Cropped Jeans</a>
#  </h3><strong class="item-price">
#  <span class="price regular">$ 29.99</span>
#  </strong><ul class="list-swatches" data-swatches-total="2">
#  <li class="item"><a class="swatch" href="/en_us/productpage.0971061001.html" style="background-color: #AFBBE0" title="Pale denim blue">
#  				Pale denim blue</a></li>
#  <li class="item"><a class="swatch" href="/en_us/productpage.0971061002.html" style="background-color: #8898AC" title="Light denim blue">
#  				Light denim blue</a></li>
#  </ul></div></article>,
#  <article class="hm-product-item" data-articlecode="1004199001" data-category="" data-energy-interval="" data-pre-access-end-date="" data-pre-access-groups="" data-pre-access-start-date="" onclick="setOsaParameters(utag_data.category_id,'SMALL','1004199001'); setNotificationTicket('Oy9wbHAvcHJvZHVjdC1saXN0LXdpdGgtY291bnQvcHJvZHVjdC1saXN0OyM7cHJvZHVjdF9rZXk7MTAwNDE5OV9ncm91cF8wMDFfZW5fdXM7MTAwNDE5OTAwMV9lbl91cztPQkpFQ1RJVkUkO05PTkU6Tk9ORTs3NTs','1004199001');">
#  <div class="image-container">
#  <a class="item-link" href="/en_us/productpage.1004199001.html" title="Skinny Cropped Jeans">
#  <img alt="Skinny Cropped JeansModel" class="item-image" data-altimage="//lp2.hm.com/hmgoepprod?set=source[/2b/16/2b164f9b92c00afd18bb5ec2e70359481b224a8d.jpg],origin[dam],category[],type[DESCRIPTIVESTILLLIFE],res[m],hmver[2]&amp;call=url[file:/product/style]" data-alttext="Skinny Cropped Jeans" data-src="//lp2.hm.com/hmgoepprod?set=source[/4c/bb/4cbba4ebc8d2c8c87b580089811b4bfe628d26c2.jpg],origin[dam],category[],type[LOOKBOOK],res[m],hmver[1]&amp;call=url[file:/product/style]"/>
#  <div class="item-buttons">
#  <button class="favorite icon-favorites js-favorite" data-not-saved-text="SAVE AS FAVORITE" data-saved-text="SAVED AS FAVORITE" data-tracking-json-template="utagFavorite" data-tracking-params="Favourites|1004199001|Skinny Cropped Jeans|MEN_SHOPBYPRODUCT : JEANS_JEANS : VIEWALL_VIEW_ALL" data-tracking-type="event">
#  				SAVE AS FAVORITE</button>
#  </div></a>
#  </div><div class="item-details">
#  <div class="marketing-marker marker-environment" style="">
#  		Conscious </div>
#  <h3 class="item-heading">
#  <a class="link" href="/en_us/productpage.1004199001.html">Skinny Cropped Jeans</a>
#  </h3><strong class="item-price">
#  <span class="price regular">$ 29.99</span>
#  </strong><ul class="list-swatches" data-swatches-total="2">
#  <li class="item"><a class="swatch" href="/en_us/productpage.1004199001.html" style="background-color: #ADBAD1" title="Light denim blue">
#  				Light denim blue</a></li>
#  <li class="item"><a class="swatch" href="/en_us/productpage.1004199002.html" style="background-color: #2E2E30" title="Black">
#  				Black</a></li>
#  </ul></div></article>,
#  <article class="hm-product-item" data-articlecode="0971061002" data-category="" data-energy-interval="" data-pre-access-end-date="" data-pre-access-groups="" data-pre-access-start-date="" onclick="setOsaParameters(utag_data.category_id,'SMALL','0971061002'); setNotificationTicket('Oy9wbHAvcHJvZHVjdC1saXN0LXdpdGgtY291bnQvcHJvZHVjdC1saXN0OyM7cHJvZHVjdF9rZXk7MDk3MTA2MV9ncm91cF8wMDJfZW5fdXM7MDk3MTA2MTAwMl9lbl91cztPQkpFQ1RJVkUkO05PTkU6Tk9ORTs3NTs','0971061002');">
#  <div class="image-container">
#  <a class="item-link" href="/en_us/productpage.0971061002.html" title="Slim Tapered Cropped Jeans">
#  <img alt="Slim Tapered Cropped JeansModel" class="item-image" data-altimage="//lp2.hm.com/hmgoepprod?set=source[/68/2d/682d675e3b70943094bb1f32a6f90a691a3b735d.jpg],origin[dam],category[],type[DESCRIPTIVESTILLLIFE],res[m],hmver[2]&amp;call=url[file:/product/style]" data-alttext="Slim Tapered Cropped Jeans" data-src="//lp2.hm.com/hmgoepprod?set=source[/52/93/52935332261e1d40c08b8d4eafb40930d8da343e.jpg],origin[dam],category[],type[LOOKBOOK],res[m],hmver[1]&amp;call=url[file:/product/style]"/>
#  <div class="item-buttons">
#  <button class="favorite icon-favorites js-favorite" data-not-saved-text="SAVE AS FAVORITE" data-saved-text="SAVED AS FAVORITE" data-tracking-json-template="utagFavorite" data-tracking-params="Favourites|0971061002|Slim Tapered Cropped Jeans|MEN_SHOPBYPRODUCT : JEANS_JEANS : VIEWALL_VIEW_ALL" data-tracking-type="event">
#  				SAVE AS FAVORITE</button>
#  </div></a>
#  </div><div class="item-details">
#  <div class="marketing-marker marker-environment" style="">
#  		Conscious </div>
#  <h3 class="item-heading">
#  <a class="link" href="/en_us/productpage.0971061002.html">Slim Tapered Cropped Jeans</a>
#  </h3><strong class="item-price">
#  <span class="price regular">$ 29.99</span>
#  </strong><ul class="list-swatches" data-swatches-total="2">
#  <li class="item"><a class="swatch" href="/en_us/productpage.0971061002.html" style="background-color: #8898AC" title="Light denim blue">
#  				Light denim blue</a></li>
#  <li class="item"><a class="swatch" href="/en_us/productpage.0971061001.html" style="background-color: #AFBBE0" title="Pale denim blue">
#  				Pale denim blue</a></li>
#  </ul></div></article>,
#  <article class="hm-product-item" data-articlecode="0985159006" data-category="men_jeans_skinny" data-energy-interval="" data-pre-access-end-date="" data-pre-access-groups="" data-pre-access-start-date="" onclick="setOsaParameters(utag_data.category_id,'SMALL','0985159006'); setNotificationTicket('Oy9wbHAvcHJvZHVjdC1saXN0LXdpdGgtY291bnQvcHJvZHVjdC1saXN0OyM7cHJvZHVjdF9rZXk7MDk4NTE1OV9ncm91cF8wMDZfZW5fdXM7MDk4NTE1OTAwNl9lbl91cztPQkpFQ1RJVkUkO05PTkU6Tk9ORTs3NTs','0985159006');">
#  <div class="image-container">
#  <a class="item-link" href="/en_us/productpage.0985159006.html" title="Skinny Jeans">
#  <img alt="Skinny JeansModel" class="item-image" data-altimage="//lp2.hm.com/hmgoepprod?set=source[/67/e2/67e212499202f0e54ca448a91bef261a414187ad.jpg],origin[dam],category[],type[DESCRIPTIVESTILLLIFE],res[m],hmver[2]&amp;call=url[file:/product/style]" data-alttext="Skinny Jeans" data-src="//lp2.hm.com/hmgoepprod?set=source[/3c/e0/3ce04055bf6ac6f1ade20695b76529c9112404f8.jpg],origin[dam],category[],type[LOOKBOOK],res[m],hmver[1]&amp;call=url[file:/product/style]"/>
#  <div class="item-buttons">
#  <button class="favorite icon-favorites js-favorite" data-not-saved-text="SAVE AS FAVORITE" data-saved-text="SAVED AS FAVORITE" data-tracking-json-template="utagFavorite" data-tracking-params="Favourites|0985159006|Skinny Jeans|MEN_SHOPBYPRODUCT : JEANS_JEANS : VIEWALL_VIEW_ALL" data-tracking-type="event">
#  				SAVE AS FAVORITE</button>
#  </div></a>
#  </div><div class="item-details">
#  <div class="marketing-marker marker-environment" style="">
#  		Conscious </div>
#  <h3 class="item-heading">
#  <a class="link" href="/en_us/productpage.0985159006.html">Skinny Jeans</a>
#  </h3><strong class="item-price">
#  <span class="price regular">$ 19.99</span>
#  </strong><ul class="list-swatches" data-swatches-total="5">
#  <li class="item"><a class="swatch" href="/en_us/productpage.0985159006.html" style="background-color: #2F323B" title="Dark denim blue">
#  				Dark denim blue</a></li>
#  <li class="item"><a class="swatch" href="/en_us/productpage.0985159001.html" style="background-color: #272628" title="Black">
#  				Black</a></li>
#  <li class="item"><a class="swatch" href="/en_us/productpage.0985159002.html" style="background-color: #6089C2" title="Denim blue">
#  				Denim blue</a></li>
#  <li class="item"><a class="swatch" href="/en_us/productpage.0985159003.html" style="background-color: #666B75" title="Dark gray">
#  				Dark gray</a></li>
#  </ul><div class="new-product">New Arrival</div>
#  </div></article>,
#  <article class="hm-product-item" data-articlecode="0985197006" data-category="men_jeans_slim" data-energy-interval="" data-pre-access-end-date="" data-pre-access-groups="" data-pre-access-start-date="" onclick="setOsaParameters(utag_data.category_id,'SMALL','0985197006'); setNotificationTicket('Oy9wbHAvcHJvZHVjdC1saXN0LXdpdGgtY291bnQvcHJvZHVjdC1saXN0OyM7cHJvZHVjdF9rZXk7MDk4NTE5N19ncm91cF8wMDZfZW5fdXM7MDk4NTE5NzAwNl9lbl91cztPQkpFQ1RJVkUkO05PTkU6Tk9ORTs3NTs','0985197006');">
#  <div class="image-container">
#  <a class="item-link" href="/en_us/productpage.0985197006.html" title="Slim Jeans">
#  <img alt="Slim JeansModel" class="item-image" data-altimage="//lp2.hm.com/hmgoepprod?set=source[/92/89/928926db92c0c86173a3d936fc7d988be3fc3dc4.jpg],origin[dam],category[men_jeans_slim],type[DESCRIPTIVESTILLLIFE],res[m],hmver[2]&amp;call=url[file:/product/style]" data-alttext="Slim Jeans" data-src="//lp2.hm.com/hmgoepprod?set=source[/43/1f/431f78e08ab6323f157999b2e8dfaed952eb1d0c.jpg],origin[dam],category[],type[LOOKBOOK],res[m],hmver[1]&amp;call=url[file:/product/style]"/>
#  <div class="item-buttons">
#  <button class="favorite icon-favorites js-favorite" data-not-saved-text="SAVE AS FAVORITE" data-saved-text="SAVED AS FAVORITE" data-tracking-json-template="utagFavorite" data-tracking-params="Favourites|0985197006|Slim Jeans|MEN_SHOPBYPRODUCT : JEANS_JEANS : VIEWALL_VIEW_ALL" data-tracking-type="event">
#  				SAVE AS FAVORITE</button>
#  </div></a>
#  </div><div class="item-details">
#  <div class="marketing-marker marker-environment" style="">
#  		Conscious </div>
#  <h3 class="item-heading">
#  <a class="link" href="/en_us/productpage.0985197006.html">Slim Jeans</a>
#  </h3><strong class="item-price">
#  <span class="price regular">$ 19.99</span>
#  </strong><ul class="list-swatches" data-swatches-total="4">
#  <li class="item"><a class="swatch" href="/en_us/productpage.0985197006.html" style="background-color: #8898AC" title="Light denim blue">
#  				Light denim blue</a></li>
#  <li class="item"><a class="swatch" href="/en_us/productpage.0985197001.html" style="background-color: #272628" title="Black">
#  				Black</a></li>
#  <li class="item"><a class="swatch" href="/en_us/productpage.0985197002.html" style="background-color: #2F323B" title="Midnight blue">
#  				Midnight blue</a></li>
#  <li class="item"><a class="swatch" href="/en_us/productpage.0985197003.html" style="background-color: #79829D" title="Denim blue">
#  				Denim blue</a></li>
#  </ul></div></article>,
#  <article class="hm-product-item" data-articlecode="0751994024" data-category="men_jeans_slim" data-energy-interval="" data-pre-access-end-date="" data-pre-access-groups="" data-pre-access-start-date="" onclick="setOsaParameters(utag_data.category_id,'SMALL','0751994024'); setNotificationTicket('Oy9wbHAvcHJvZHVjdC1saXN0LXdpdGgtY291bnQvcHJvZHVjdC1saXN0OyM7cHJvZHVjdF9rZXk7MDc1MTk5NF9ncm91cF8wMjRfZW5fdXM7MDc1MTk5NDAyNF9lbl91cztPQkpFQ1RJVkUkO05PTkU6Tk9ORTs3NTs','0751994024');">
#  <div class="image-container">
#  <a class="item-link" href="/en_us/productpage.0751994024.html" title="Slim Jeans">
#  <img alt="Slim JeansModel" class="item-image" data-altimage="//lp2.hm.com/hmgoepprod?set=source[/8d/7c/8d7c087a7cdd6510aeaadee95436d12c7617291f.jpg],origin[dam],category[men_jeans_slim],type[DESCRIPTIVESTILLLIFE],res[m],hmver[2]&amp;call=url[file:/product/style]" data-alttext="Slim Jeans" data-src="//lp2.hm.com/hmgoepprod?set=source[/98/fb/98fb75cad2749ce93f49524b5fd5ede946438d2c.jpg],origin[dam],category[men_jeans_slim],type[LOOKBOOK],res[m],hmver[1]&amp;call=url[file:/product/style]"/>
#  <div class="item-buttons">
#  <button class="favorite icon-favorites js-favorite" data-not-saved-text="SAVE AS FAVORITE" data-saved-text="SAVED AS FAVORITE" data-tracking-json-template="utagFavorite" data-tracking-params="Favourites|0751994024|Slim Jeans|MEN_SHOPBYPRODUCT : JEANS_JEANS : VIEWALL_VIEW_ALL" data-tracking-type="event">
#  				SAVE AS FAVORITE</button>
#  </div></a>
#  </div><div class="item-details">
#  <h3 class="item-heading">
#  <a class="link" href="/en_us/productpage.0751994024.html">Slim Jeans</a>
#  </h3><strong class="item-price">
#  <span class="price regular">$ 29.99</span>
#  </strong><ul class="list-swatches" data-swatches-total="5">
#  <li class="item"><a class="swatch" href="/en_us/productpage.0751994024.html" style="background-color: #383638" title="Black denim">
#  				Black denim</a></li>
#  <li class="item"><a class="swatch" href="/en_us/productpage.0751994009.html" style="background-color: #737FA1" title="Dark blue denim">
#  				Dark blue denim</a></li>
#  <li class="item"><a class="swatch" href="/en_us/productpage.0751994014.html" style="background-color: #94989F" title="Light gray">
#  				Light gray</a></li>
#  <li class="item"><a class="swatch" href="/en_us/productpage.0751994018.html" style="background-color: #79829D" title="Denim blue">
#  				Denim blue</a></li>
#  </ul></div></article>,
#  <article class="hm-product-item" data-articlecode="0985159004" data-category="men_jeans_skinny" data-energy-interval="" data-pre-access-end-date="" data-pre-access-groups="" data-pre-access-start-date="" onclick="setOsaParameters(utag_data.category_id,'SMALL','0985159004'); setNotificationTicket('Oy9wbHAvcHJvZHVjdC1saXN0LXdpdGgtY291bnQvcHJvZHVjdC1saXN0OyM7cHJvZHVjdF9rZXk7MDk4NTE1OV9ncm91cF8wMDRfZW5fdXM7MDk4NTE1OTAwNF9lbl91cztPQkpFQ1RJVkUkO05PTkU6Tk9ORTs3NTs','0985159004');">
#  <div class="image-container">
#  <a class="item-link" href="/en_us/productpage.0985159004.html" title="Skinny Jeans">
#  <img alt="Skinny JeansModel" class="item-image" data-altimage="//lp2.hm.com/hmgoepprod?set=source[/e0/cd/e0cd1f7369528e3fd0e1fef3c0a3a1990f06ad87.jpg],origin[dam],category[],type[DESCRIPTIVESTILLLIFE],res[m],hmver[2]&amp;call=url[file:/product/style]" data-alttext="Skinny Jeans" data-src="//lp2.hm.com/hmgoepprod?set=source[/6e/fa/6efa0c9f4d03dd36dae4454a508b2d9a8a05f3ab.jpg],origin[dam],category[],type[LOOKBOOK],res[m],hmver[1]&amp;call=url[file:/product/style]"/>
#  <div class="item-buttons">
#  <button class="favorite icon-favorites js-favorite" data-not-saved-text="SAVE AS FAVORITE" data-saved-text="SAVED AS FAVORITE" data-tracking-json-template="utagFavorite" data-tracking-params="Favourites|0985159004|Skinny Jeans|MEN_SHOPBYPRODUCT : JEANS_JEANS : VIEWALL_VIEW_ALL" data-tracking-type="event">
#  				SAVE AS FAVORITE</button>
#  </div></a>
#  </div><div class="item-details">
#  <div class="marketing-marker marker-environment" style="">
#  		Conscious </div>
#  <h3 class="item-heading">
#  <a class="link" href="/en_us/productpage.0985159004.html">Skinny Jeans</a>
#  </h3><strong class="item-price">
#  <span class="price regular">$ 19.99</span>
#  </strong><ul class="list-swatches" data-swatches-total="5">
#  <li class="item"><a class="swatch" href="/en_us/productpage.0985159004.html" style="background-color: #8898AC" title="Light denim blue">
#  				Light denim blue</a></li>
#  <li class="item"><a class="swatch" href="/en_us/productpage.0985159001.html" style="background-color: #272628" title="Black">
#  				Black</a></li>
#  <li class="item"><a class="swatch" href="/en_us/productpage.0985159002.html" style="background-color: #6089C2" title="Denim blue">
#  				Denim blue</a></li>
#  <li class="item"><a class="swatch" href="/en_us/productpage.0985159003.html" style="background-color: #666B75" title="Dark gray">
#  				Dark gray</a></li>
#  </ul></div></article>,
#  <article class="hm-product-item" data-articlecode="0811993021" data-category="men_jeans_regular" data-energy-interval="" data-pre-access-end-date="" data-pre-access-groups="" data-pre-access-start-date="" onclick="setOsaParameters(utag_data.category_id,'SMALL','0811993021'); setNotificationTicket('Oy9wbHAvcHJvZHVjdC1saXN0LXdpdGgtY291bnQvcHJvZHVjdC1saXN0OyM7cHJvZHVjdF9rZXk7MDgxMTk5M19ncm91cF8wMjFfZW5fdXM7MDgxMTk5MzAyMV9lbl91cztPQkpFQ1RJVkUkO05PTkU6Tk9ORTs3NTs','0811993021');">
#  <div class="image-container">
#  <a class="item-link" href="/en_us/productpage.0811993021.html" title="Regular Jeans">
#  <img alt="Regular JeansModel" class="item-image" data-altimage="//lp2.hm.com/hmgoepprod?set=source[/fc/ba/fcba25c2a546ed633a5eca1b14f46219bb196513.jpg],origin[dam],category[men_jeans_straight],type[DESCRIPTIVESTILLLIFE],res[m],hmver[1]&amp;call=url[file:/product/style]" data-alttext="Regular Jeans" data-src="//lp2.hm.com/hmgoepprod?set=source[/f8/99/f8995cccd97ac186a9aaa9570f946974efaa1d9f.jpg],origin[dam],category[men_jeans_regular],type[LOOKBOOK],res[m],hmver[1]&amp;call=url[file:/product/style]"/>
#  <div class="item-buttons">
#  <button class="favorite icon-favorites js-favorite" data-not-saved-text="SAVE AS FAVORITE" data-saved-text="SAVED AS FAVORITE" data-tracking-json-template="utagFavorite" data-tracking-params="Favourites|0811993021|Regular Jeans|MEN_SHOPBYPRODUCT : JEANS_JEANS : VIEWALL_VIEW_ALL" data-tracking-type="event">
#  				SAVE AS FAVORITE</button>
#  </div></a>
#  </div><div class="item-details">
#  <div class="marketing-marker marker-environment" style="">
#  		Conscious </div>
#  <h3 class="item-heading">
#  <a class="link" href="/en_us/productpage.0811993021.html">Regular Jeans</a>
#  </h3><strong class="item-price">
#  <span class="price regular">$ 29.99</span>
#  </strong><ul class="list-swatches" data-swatches-total="8">
#  <li class="item"><a class="swatch" href="/en_us/productpage.0811993021.html" style="background-color: #272628" title="Black">
#  				Black</a></li>
#  <li class="item"><a class="swatch" href="/en_us/productpage.0811993003.html" style="background-color: #4C5164" title="Dark denim blue">
#  				Dark denim blue</a></li>
#  <li class="item"><a class="swatch" href="/en_us/productpage.0811993007.html" style="background-color: #8898AC" title="Light denim blue">
#  				Light denim blue</a></li>
#  <li class="item"><a class="swatch" href="/en_us/productpage.0811993022.html" style="background-color: #EEEDE1" title="Cream">
#  				Cream</a></li>
#  </ul></div></article>,
#  <article class="hm-product-item" data-articlecode="1004199002" data-category="" data-energy-interval="" data-pre-access-end-date="" data-pre-access-groups="" data-pre-access-start-date="" onclick="setOsaParameters(utag_data.category_id,'SMALL','1004199002'); setNotificationTicket('Oy9wbHAvcHJvZHVjdC1saXN0LXdpdGgtY291bnQvcHJvZHVjdC1saXN0OyM7cHJvZHVjdF9rZXk7MTAwNDE5OV9ncm91cF8wMDJfZW5fdXM7MTAwNDE5OTAwMl9lbl91cztPQkpFQ1RJVkUkO05PTkU6Tk9ORTs3NTs','1004199002');">
#  <div class="image-container">
#  <a class="item-link" href="/en_us/productpage.1004199002.html" title="Skinny Cropped Jeans">
#  <img alt="Skinny Cropped JeansModel" class="item-image" data-altimage="//lp2.hm.com/hmgoepprod?set=source[/95/fe/95fe0c8d937eed977512d685f7ab8b2d64464a6d.jpg],origin[dam],category[],type[DESCRIPTIVESTILLLIFE],res[m],hmver[2]&amp;call=url[file:/product/style]" data-alttext="Skinny Cropped Jeans" data-src="//lp2.hm.com/hmgoepprod?set=source[/36/d5/36d598895ad20698bdc54748038afa1ca98be34b.jpg],origin[dam],category[],type[LOOKBOOK],res[m],hmver[1]&amp;call=url[file:/product/style]"/>
#  <div class="item-buttons">
#  <button class="favorite icon-favorites js-favorite" data-not-saved-text="SAVE AS FAVORITE" data-saved-text="SAVED AS FAVORITE" data-tracking-json-template="utagFavorite" data-tracking-params="Favourites|1004199002|Skinny Cropped Jeans|MEN_SHOPBYPRODUCT : JEANS_JEANS : VIEWALL_VIEW_ALL" data-tracking-type="event">
#  				SAVE AS FAVORITE</button>
#  </div></a>
#  </div><div class="item-details">
#  <div class="marketing-marker marker-environment" style="">
#  		Conscious </div>
#  <h3 class="item-heading">
#  <a class="link" href="/en_us/productpage.1004199002.html">Skinny Cropped Jeans</a>
#  </h3><strong class="item-price">
#  <span class="price regular">$ 29.99</span>
#  </strong><ul class="list-swatches" data-swatches-total="2">
#  <li class="item"><a class="swatch" href="/en_us/productpage.1004199002.html" style="background-color: #2E2E30" title="Black">
#  				Black</a></li>
#  <li class="item"><a class="swatch" href="/en_us/productpage.1004199001.html" style="background-color: #ADBAD1" title="Light denim blue">
#  				Light denim blue</a></li>
#  </ul></div></article>,
#  <article class="hm-product-item" data-articlecode="0751994031" data-category="men_jeans_slim" data-energy-interval="" data-pre-access-end-date="" data-pre-access-groups="" data-pre-access-start-date="" onclick="setOsaParameters(utag_data.category_id,'SMALL','0751994031'); setNotificationTicket('Oy9wbHAvcHJvZHVjdC1saXN0LXdpdGgtY291bnQvcHJvZHVjdC1saXN0OyM7cHJvZHVjdF9rZXk7MDc1MTk5NF9ncm91cF8wMzFfZW5fdXM7MDc1MTk5NDAzMV9lbl91cztPQkpFQ1RJVkUkO05PTkU6Tk9ORTs3NTs','0751994031');">
#  <div class="image-container">
#  <a class="item-link" href="/en_us/productpage.0751994031.html" title="Slim Jeans">
#  <img alt="Slim JeansModel" class="item-image" data-altimage="//lp2.hm.com/hmgoepprod?set=source[/c8/cb/c8cb802916bfc285b326467aafee6a923c365013.jpg],origin[dam],category[men_jeans_slim],type[DESCRIPTIVESTILLLIFE],res[m],hmver[2]&amp;call=url[file:/product/style]" data-alttext="Slim Jeans" data-src="//lp2.hm.com/hmgoepprod?set=source[/64/3d/643d2bb8c2a6734c32f3c16b4911df3d101d9655.jpg],origin[dam],category[men_jeans_slim],type[LOOKBOOK],res[m],hmver[1]&amp;call=url[file:/product/style]"/>
#  <div class="item-buttons">
#  <button class="favorite icon-favorites js-favorite" data-not-saved-text="SAVE AS FAVORITE" data-saved-text="SAVED AS FAVORITE" data-tracking-json-template="utagFavorite" data-tracking-params="Favourites|0751994031|Slim Jeans|MEN_SHOPBYPRODUCT : JEANS_JEANS : VIEWALL_VIEW_ALL" data-tracking-type="event">
#  				SAVE AS FAVORITE</button>
#  </div></a>
#  </div><div class="item-details">
#  <div class="marketing-marker marker-environment" style="">
#  		Conscious </div>
#  <h3 class="item-heading">
#  <a class="link" href="/en_us/productpage.0751994031.html">Slim Jeans</a>
#  </h3><strong class="item-price">
#  <span class="price regular">$ 29.99</span>
#  </strong><ul class="list-swatches" data-swatches-total="5">
#  <li class="item"><a class="swatch" href="/en_us/productpage.0751994031.html" style="background-color: #8898AC" title="Light blue">
#  				Light blue</a></li>
#  <li class="item"><a class="swatch" href="/en_us/productpage.0751994009.html" style="background-color: #737FA1" title="Dark blue denim">
#  				Dark blue denim</a></li>
#  <li class="item"><a class="swatch" href="/en_us/productpage.0751994014.html" style="background-color: #94989F" title="Light gray">
#  				Light gray</a></li>
#  <li class="item"><a class="swatch" href="/en_us/productpage.0751994018.html" style="background-color: #79829D" title="Denim blue">
#  				Denim blue</a></li>
#  </ul></div></article>,
#  <article class="hm-product-item" data-articlecode="1004476005" data-category="" data-energy-interval="" data-pre-access-end-date="" data-pre-access-groups="" data-pre-access-start-date="" onclick="setOsaParameters(utag_data.category_id,'SMALL','1004476005'); setNotificationTicket('Oy9wbHAvcHJvZHVjdC1saXN0LXdpdGgtY291bnQvcHJvZHVjdC1saXN0OyM7cHJvZHVjdF9rZXk7MTAwNDQ3Nl9ncm91cF8wMDVfZW5fdXM7MTAwNDQ3NjAwNV9lbl91cztPQkpFQ1RJVkUkO05PTkU6Tk9ORTs3NTs','1004476005');">
#  <div class="image-container">
#  <a class="item-link" href="/en_us/productpage.1004476005.html" title="Freefit® Slim Jeans">
#  <img alt="Freefit® Slim JeansModel" class="item-image" data-altimage="//lp2.hm.com/hmgoepprod?set=source[/e1/02/e10282fc24c71562da62d1401cd7d77c40ffcaa1.jpg],origin[dam],category[],type[DESCRIPTIVESTILLLIFE],res[m],hmver[2]&amp;call=url[file:/product/style]" data-alttext="Freefit® Slim Jeans" data-src="//lp2.hm.com/hmgoepprod?set=source[/a4/11/a411d6ebb5a0a808e021b93127877ba75e2cebd1.jpg],origin[dam],category[],type[LOOKBOOK],res[m],hmver[1]&amp;call=url[file:/product/style]"/>
#  <div class="item-buttons">
#  <button class="favorite icon-favorites js-favorite" data-not-saved-text="SAVE AS FAVORITE" data-saved-text="SAVED AS FAVORITE" data-tracking-json-template="utagFavorite" data-tracking-params="Favourites|1004476005|Freefit® Slim Jeans|MEN_SHOPBYPRODUCT : JEANS_JEANS : VIEWALL_VIEW_ALL" data-tracking-type="event">
#  				SAVE AS FAVORITE</button>
#  </div></a>
#  </div><div class="item-details">
#  <div class="marketing-marker marker-environment" style="">
#  		Conscious </div>
#  <h3 class="item-heading">
#  <a class="link" href="/en_us/productpage.1004476005.html">Freefit® Slim Jeans</a>
#  </h3><strong class="item-price">
#  <span class="price regular">$ 49.99</span>
#  </strong><ul class="list-swatches" data-swatches-total="3">
#  <li class="item"><a class="swatch" href="/en_us/productpage.1004476005.html" style="background-color: #272628" title="Black/No fade black">
#  				Black/No fade black</a></li>
#  <li class="item"><a class="swatch" href="/en_us/productpage.1004476001.html" style="background-color: #8898AC" title="Light denim blue">
#  				Light denim blue</a></li>
#  <li class="item"><a class="swatch" href="/en_us/productpage.1004476004.html" style="background-color: #4C5164" title="Dark denim blue">
#  				Dark denim blue</a></li>
#  </ul></div></article>,
#  <article class="hm-product-item" data-articlecode="1004476004" data-category="" data-energy-interval="" data-pre-access-end-date="" data-pre-access-groups="" data-pre-access-start-date="" onclick="setOsaParameters(utag_data.category_id,'SMALL','1004476004'); setNotificationTicket('Oy9wbHAvcHJvZHVjdC1saXN0LXdpdGgtY291bnQvcHJvZHVjdC1saXN0OyM7cHJvZHVjdF9rZXk7MTAwNDQ3Nl9ncm91cF8wMDRfZW5fdXM7MTAwNDQ3NjAwNF9lbl91cztPQkpFQ1RJVkUkO05PTkU6Tk9ORTs3NTs','1004476004');">
#  <div class="image-container">
#  <a class="item-link" href="/en_us/productpage.1004476004.html" title="Freefit® Slim Jeans">
#  <img alt="Freefit® Slim JeansModel" class="item-image" data-altimage="//lp2.hm.com/hmgoepprod?set=source[/40/51/405126f0dee80c548faa213d2b532a9639115522.jpg],origin[dam],category[],type[DESCRIPTIVESTILLLIFE],res[m],hmver[2]&amp;call=url[file:/product/style]" data-alttext="Freefit® Slim Jeans" data-src="//lp2.hm.com/hmgoepprod?set=source[/e3/71/e37146fe7eed2f58e6b91d95ba033d149e11de95.jpg],origin[dam],category[],type[LOOKBOOK],res[m],hmver[1]&amp;call=url[file:/product/style]"/>
#  <div class="item-buttons">
#  <button class="favorite icon-favorites js-favorite" data-not-saved-text="SAVE AS FAVORITE" data-saved-text="SAVED AS FAVORITE" data-tracking-json-template="utagFavorite" data-tracking-params="Favourites|1004476004|Freefit® Slim Jeans|MEN_SHOPBYPRODUCT : JEANS_JEANS : VIEWALL_VIEW_ALL" data-tracking-type="event">
#  				SAVE AS FAVORITE</button>
#  </div></a>
#  </div><div class="item-details">
#  <div class="marketing-marker marker-environment" style="">
#  		Conscious </div>
#  <h3 class="item-heading">
#  <a class="link" href="/en_us/productpage.1004476004.html">Freefit® Slim Jeans</a>
#  </h3><strong class="item-price">
#  <span class="price regular">$ 49.99</span>
#  </strong><ul class="list-swatches" data-swatches-total="3">
#  <li class="item"><a class="swatch" href="/en_us/productpage.1004476004.html" style="background-color: #4C5164" title="Dark denim blue">
#  				Dark denim blue</a></li>
#  <li class="item"><a class="swatch" href="/en_us/productpage.1004476001.html" style="background-color: #8898AC" title="Light denim blue">
#  				Light denim blue</a></li>
#  <li class="item"><a class="swatch" href="/en_us/productpage.1004476005.html" style="background-color: #272628" title="Black/No fade black">
#  				Black/No fade black</a></li>
#  </ul></div></article>,
#  <article class="hm-product-item" data-articlecode="0974202001" data-category="" data-energy-interval="" data-pre-access-end-date="" data-pre-access-groups="" data-pre-access-start-date="" onclick="setOsaParameters(utag_data.category_id,'SMALL','0974202001'); setNotificationTicket('Oy9wbHAvcHJvZHVjdC1saXN0LXdpdGgtY291bnQvcHJvZHVjdC1saXN0OyM7cHJvZHVjdF9rZXk7MDk3NDIwMl9ncm91cF8wMDFfZW5fdXM7MDk3NDIwMjAwMV9lbl91cztPQkpFQ1RJVkUkO05PTkU6Tk9ORTs3NTs','0974202001');">
#  <div class="image-container">
#  <a class="item-link" href="/en_us/productpage.0974202001.html" title="Regular Denim Joggers">
#  <img alt="Regular Denim JoggersModel" class="item-image" data-altimage="//lp2.hm.com/hmgoepprod?set=source[/a5/29/a529c650edb156630ab67a03ba80a0ed329ca005.jpg],origin[dam],category[],type[DESCRIPTIVESTILLLIFE],res[m],hmver[2]&amp;call=url[file:/product/style]" data-alttext="Regular Denim Joggers" data-src="//lp2.hm.com/hmgoepprod?set=source[/87/76/8776c8ab9accede38225b6106bc6aee5830fa439.jpg],origin[dam],category[],type[LOOKBOOK],res[m],hmver[1]&amp;call=url[file:/product/style]"/>
#  <div class="item-buttons">
#  <button class="favorite icon-favorites js-favorite" data-not-saved-text="SAVE AS FAVORITE" data-saved-text="SAVED AS FAVORITE" data-tracking-json-template="utagFavorite" data-tracking-params="Favourites|0974202001|Regular Denim Joggers|MEN_SHOPBYPRODUCT : JEANS_JEANS : VIEWALL_VIEW_ALL" data-tracking-type="event">
#  				SAVE AS FAVORITE</button>
#  </div></a>
#  </div><div class="item-details">
#  <div class="marketing-marker marker-environment" style="">
#  		Conscious </div>
#  <h3 class="item-heading">
#  <a class="link" href="/en_us/productpage.0974202001.html">Regular Denim Joggers</a>
#  </h3><strong class="item-price">
#  <span class="price regular">$ 29.99</span>
#  </strong><ul class="list-swatches" data-swatches-total="3">
#  <li class="item"><a class="swatch" href="/en_us/productpage.0974202001.html" style="background-color: #8898AC" title="Light denim blue">
#  				Light denim blue</a></li>
#  <li class="item"><a class="swatch" href="/en_us/productpage.0974202002.html" style="background-color: #79829D" title="Denim blue">
#  				Denim blue</a></li>
#  <li class="item"><a class="swatch" href="/en_us/productpage.0974202003.html" style="background-color: #2E2E30" title="Black">
#  				Black</a></li>
#  </ul></div></article>,
# ...
#  				SAVE AS FAVORITE</button>
#  </div></a>
#  </div><div class="item-details">
#  <h3 class="item-heading">
#  <a class="link" href="/en_us/productpage.0636207006.html">Slim Jeans</a>
#  </h3><strong class="item-price">
#  <span class="price regular">$ 19.99</span>
#  </strong><ul class="list-swatches" data-swatches-total="7">
#  <li class="item"><a class="swatch" href="/en_us/productpage.0636207006.html" style="background-color: #272628" title="Black">
#  				Black</a></li>
#  <li class="item"><a class="swatch" href="/en_us/productpage.0636207001.html" style="background-color: #4C5164" title="Dark denim blue">
#  				Dark denim blue</a></li>
#  <li class="item"><a class="swatch" href="/en_us/productpage.0636207010.html" style="background-color: #79829D" title="Light denim blue">
#  				Light denim blue</a></li>
#  <li class="item"><a class="swatch" href="/en_us/productpage.0636207011.html" style="background-color: #2F323B" title="Midnight blue">
#  				Midnight blue</a></li>
#  </ul></div></article>,
#  <article class="hm-product-item" data-articlecode="0636207010" data-category="" data-energy-interval="" data-pre-access-end-date="" data-pre-access-groups="" data-pre-access-start-date="" onclick="setOsaParameters(utag_data.category_id,'SMALL','0636207010'); setNotificationTicket('Oy9wbHAvcHJvZHVjdC1saXN0LXdpdGgtY291bnQvcHJvZHVjdC1saXN0OyM7cHJvZHVjdF9rZXk7MDYzNjIwN19ncm91cF8wMTBfZW5fdXM7MDYzNjIwNzAxMF9lbl91cztPQkpFQ1RJVkUkO05PTkU6Tk9ORTs3NTs','0636207010');">
#  <div class="image-container">
#  <a class="item-link" href="/en_us/productpage.0636207010.html" title="Slim Jeans">
#  <img alt="Slim JeansModel" class="item-image" data-altimage="//lp2.hm.com/hmgoepprod?set=source[/09/eb/09eb36bd2c323ec6ffac19e9e222b175fe21233b.jpg],origin[dam],category[men_jeans_slim],type[DESCRIPTIVESTILLLIFE],res[m],hmver[1]&amp;call=url[file:/product/style]" data-alttext="Slim Jeans" data-src="//lp2.hm.com/hmgoepprod?set=source[/09/eb/09eb36bd2c323ec6ffac19e9e222b175fe21233b.jpg],origin[dam],category[men_jeans_slim],type[DESCRIPTIVESTILLLIFE],res[m],hmver[1]&amp;call=url[file:/product/style]"/>
#  <div class="item-buttons">
#  <div class="promotion-marker" data-tooltip="">
#  				 Low Price</div>
#  <button class="favorite icon-favorites js-favorite" data-not-saved-text="SAVE AS FAVORITE" data-saved-text="SAVED AS FAVORITE" data-tracking-json-template="utagFavorite" data-tracking-params="Favourites|0636207010|Slim Jeans|MEN_SHOPBYPRODUCT : JEANS_JEANS : VIEWALL_VIEW_ALL" data-tracking-type="event">
#  				SAVE AS FAVORITE</button>
#  </div></a>
#  </div><div class="item-details">
#  <h3 class="item-heading">
#  <a class="link" href="/en_us/productpage.0636207010.html">Slim Jeans</a>
#  </h3><strong class="item-price">
#  <span class="price regular">$ 19.99</span>
#  </strong><ul class="list-swatches" data-swatches-total="7">
#  <li class="item"><a class="swatch" href="/en_us/productpage.0636207010.html" style="background-color: #79829D" title="Light denim blue">
#  				Light denim blue</a></li>
#  <li class="item"><a class="swatch" href="/en_us/productpage.0636207001.html" style="background-color: #4C5164" title="Dark denim blue">
#  				Dark denim blue</a></li>
#  <li class="item"><a class="swatch" href="/en_us/productpage.0636207006.html" style="background-color: #272628" title="Black">
#  				Black</a></li>
#  <li class="item"><a class="swatch" href="/en_us/productpage.0636207011.html" style="background-color: #2F323B" title="Midnight blue">
#  				Midnight blue</a></li>
#  </ul></div></article>,
#  <article class="hm-product-item" data-articlecode="0720504001" data-category="men_jeans_skinny" data-energy-interval="" data-pre-access-end-date="" data-pre-access-groups="" data-pre-access-start-date="" onclick="setOsaParameters(utag_data.category_id,'SMALL','0720504001'); setNotificationTicket('Oy9wbHAvcHJvZHVjdC1saXN0LXdpdGgtY291bnQvcHJvZHVjdC1saXN0OyM7cHJvZHVjdF9rZXk7MDcyMDUwNF9ncm91cF8wMDFfZW5fdXM7MDcyMDUwNDAwMV9lbl91cztPQkpFQ1RJVkUkO05PTkU6Tk9ORTs3NTs','0720504001');">
#  <div class="image-container">
#  <a class="item-link" href="/en_us/productpage.0720504001.html" title="Skinny Jeans">
#  <img alt="Skinny JeansModel" class="item-image" data-altimage="//lp2.hm.com/hmgoepprod?set=source[/5d/0d/5d0d93e035dba0a9a40f1c93e35ba0d33ea02822.jpg],origin[dam],category[men_jeans_skinny],type[DESCRIPTIVESTILLLIFE],res[m],hmver[1]&amp;call=url[file:/product/style]" data-alttext="Skinny Jeans" data-src="//lp2.hm.com/hmgoepprod?set=source[/5d/0d/5d0d93e035dba0a9a40f1c93e35ba0d33ea02822.jpg],origin[dam],category[men_jeans_skinny],type[DESCRIPTIVESTILLLIFE],res[m],hmver[1]&amp;call=url[file:/product/style]"/>
#  <div class="item-buttons">
#  <div class="promotion-marker" data-tooltip="">
#  				 Low Price</div>
#  <button class="favorite icon-favorites js-favorite" data-not-saved-text="SAVE AS FAVORITE" data-saved-text="SAVED AS FAVORITE" data-tracking-json-template="utagFavorite" data-tracking-params="Favourites|0720504001|Skinny Jeans|MEN_SHOPBYPRODUCT : JEANS_JEANS : VIEWALL_VIEW_ALL" data-tracking-type="event">
#  				SAVE AS FAVORITE</button>
#  </div></a>
#  </div><div class="item-details">
#  <h3 class="item-heading">
#  <a class="link" href="/en_us/productpage.0720504001.html">Skinny Jeans</a>
#  </h3><strong class="item-price">
#  <span class="price regular">$ 24.99</span>
#  </strong><ul class="list-swatches" data-swatches-total="6">
#  <li class="item"><a class="swatch" href="/en_us/productpage.0720504001.html" style="background-color: #272628" title="Black">
#  				Black</a></li>
#  <li class="item"><a class="swatch" href="/en_us/productpage.0720504002.html" style="background-color: #4C5164" title="Dark denim blue">
#  				Dark denim blue</a></li>
#  <li class="item"><a class="swatch" href="/en_us/productpage.0720504008.html" style="background-color: #666B75" title="Dark gray">
#  				Dark gray</a></li>
#  <li class="item"><a class="swatch" href="/en_us/productpage.0720504010.html" style="background-color: #6089C2" title="Denim blue">
#  				Denim blue</a></li>
#  </ul></div></article>,
#  <article class="hm-product-item" data-articlecode="0720504008" data-category="men_jeans_skinny" data-energy-interval="" data-pre-access-end-date="" data-pre-access-groups="" data-pre-access-start-date="" onclick="setOsaParameters(utag_data.category_id,'SMALL','0720504008'); setNotificationTicket('Oy9wbHAvcHJvZHVjdC1saXN0LXdpdGgtY291bnQvcHJvZHVjdC1saXN0OyM7cHJvZHVjdF9rZXk7MDcyMDUwNF9ncm91cF8wMDhfZW5fdXM7MDcyMDUwNDAwOF9lbl91cztPQkpFQ1RJVkUkO05PTkU6Tk9ORTs3NTs','0720504008');">
#  <div class="image-container">
#  <a class="item-link" href="/en_us/productpage.0720504008.html" title="Skinny Jeans">
#  <img alt="Skinny JeansModel" class="item-image" data-altimage="//lp2.hm.com/hmgoepprod?set=source[/5a/35/5a357e9da38ecf5513c42b4096aadff06ec64594.jpg],origin[dam],category[men_jeans_skinny],type[DESCRIPTIVESTILLLIFE],res[m],hmver[2]&amp;call=url[file:/product/style]" data-alttext="Skinny Jeans" data-src="//lp2.hm.com/hmgoepprod?set=source[/5a/35/5a357e9da38ecf5513c42b4096aadff06ec64594.jpg],origin[dam],category[men_jeans_skinny],type[DESCRIPTIVESTILLLIFE],res[m],hmver[2]&amp;call=url[file:/product/style]"/>
#  <div class="item-buttons">
#  <div class="promotion-marker" data-tooltip="">
#  				 Low Price</div>
#  <button class="favorite icon-favorites js-favorite" data-not-saved-text="SAVE AS FAVORITE" data-saved-text="SAVED AS FAVORITE" data-tracking-json-template="utagFavorite" data-tracking-params="Favourites|0720504008|Skinny Jeans|MEN_SHOPBYPRODUCT : JEANS_JEANS : VIEWALL_VIEW_ALL" data-tracking-type="event">
#  				SAVE AS FAVORITE</button>
#  </div></a>
#  </div><div class="item-details">
#  <h3 class="item-heading">
#  <a class="link" href="/en_us/productpage.0720504008.html">Skinny Jeans</a>
#  </h3><strong class="item-price">
#  <span class="price regular">$ 24.99</span>
#  </strong><ul class="list-swatches" data-swatches-total="6">
#  <li class="item"><a class="swatch" href="/en_us/productpage.0720504008.html" style="background-color: #666B75" title="Dark gray">
#  				Dark gray</a></li>
#  <li class="item"><a class="swatch" href="/en_us/productpage.0720504001.html" style="background-color: #272628" title="Black">
#  				Black</a></li>
#  <li class="item"><a class="swatch" href="/en_us/productpage.0720504002.html" style="background-color: #4C5164" title="Dark denim blue">
#  				Dark denim blue</a></li>
#  <li class="item"><a class="swatch" href="/en_us/productpage.0720504010.html" style="background-color: #6089C2" title="Denim blue">
#  				Denim blue</a></li>
#  </ul></div></article>,
#  <article class="hm-product-item" data-articlecode="0868115001" data-category="men_jeans_skinny" data-energy-interval="" data-pre-access-end-date="" data-pre-access-groups="" data-pre-access-start-date="" onclick="setOsaParameters(utag_data.category_id,'SMALL','0868115001'); setNotificationTicket('Oy9wbHAvcHJvZHVjdC1saXN0LXdpdGgtY291bnQvcHJvZHVjdC1saXN0OyM7cHJvZHVjdF9rZXk7MDg2ODExNV9ncm91cF8wMDFfZW5fdXM7MDg2ODExNTAwMV9lbl91cztPQkpFQ1RJVkUkO05PTkU6Tk9ORTs3NTs','0868115001');">
#  <div class="image-container">
#  <a class="item-link" href="/en_us/productpage.0868115001.html" title="Skinny Cropped Jeans">
#  <img alt="Skinny Cropped JeansModel" class="item-image" data-altimage="//lp2.hm.com/hmgoepprod?set=source[/d6/bc/d6bc0fa801069ae986dec21ab5b09fa67d629f72.jpg],origin[dam],category[men_jeans_skinny],type[DESCRIPTIVESTILLLIFE],res[m],hmver[1]&amp;call=url[file:/product/style]" data-alttext="Skinny Cropped Jeans" data-src="//lp2.hm.com/hmgoepprod?set=source[/65/3f/653fe98ba4311d1d3a6e15172b833347c4d0b377.jpg],origin[dam],category[men_jeans_skinny],type[LOOKBOOK],res[m],hmver[1]&amp;call=url[file:/product/style]"/>
#  <div class="item-buttons">
#  <button class="favorite icon-favorites js-favorite" data-not-saved-text="SAVE AS FAVORITE" data-saved-text="SAVED AS FAVORITE" data-tracking-json-template="utagFavorite" data-tracking-params="Favourites|0868115001|Skinny Cropped Jeans|MEN_SHOPBYPRODUCT : JEANS_JEANS : VIEWALL_VIEW_ALL" data-tracking-type="event">
#  				SAVE AS FAVORITE</button>
#  </div></a>
#  </div><div class="item-details">
#  <h3 class="item-heading">
#  <a class="link" href="/en_us/productpage.0868115001.html">Skinny Cropped Jeans</a>
#  </h3><strong class="item-price">
#  <span class="price regular">$ 29.99</span>
#  </strong><ul class="list-swatches" data-swatches-total="4">
#  <li class="item"><a class="swatch" href="/en_us/productpage.0868115001.html" style="background-color: #2E2E30" title="Black">
#  				Black</a></li>
#  <li class="item"><a class="swatch" href="/en_us/productpage.0868115005.html" style="background-color: #ADBAD1" title="Light denim blue">
#  				Light denim blue</a></li>
#  <li class="item"><a class="swatch" href="/en_us/productpage.0868115006.html" style="background-color: #FFFFFF" title="White">
#  				White</a></li>
#  <li class="item"><a class="swatch" href="/en_us/productpage.0868115007.html" style="background-color: #C4CAD7" title="Light blue">
#  				Light blue</a></li>
#  </ul></div></article>,
#  <article class="hm-product-item" data-articlecode="0985159002" data-category="men_jeans_skinny" data-energy-interval="" data-pre-access-end-date="" data-pre-access-groups="" data-pre-access-start-date="" onclick="setOsaParameters(utag_data.category_id,'SMALL','0985159002'); setNotificationTicket('Oy9wbHAvcHJvZHVjdC1saXN0LXdpdGgtY291bnQvcHJvZHVjdC1saXN0OyM7cHJvZHVjdF9rZXk7MDk4NTE1OV9ncm91cF8wMDJfZW5fdXM7MDk4NTE1OTAwMl9lbl91cztPQkpFQ1RJVkUkO05PTkU6Tk9ORTs3NTs','0985159002');">
#  <div class="image-container">
#  <a class="item-link" href="/en_us/productpage.0985159002.html" title="Skinny Jeans">
#  <img alt="Skinny JeansModel" class="item-image" data-altimage="//lp2.hm.com/hmgoepprod?set=source[/8d/59/8d592c0d3183668187ca199ea5366e04ed6e35b6.jpg],origin[dam],category[],type[DESCRIPTIVESTILLLIFE],res[m],hmver[2]&amp;call=url[file:/product/style]" data-alttext="Skinny Jeans" data-src="//lp2.hm.com/hmgoepprod?set=source[/83/90/83906d6c2f5c6b94e8cf9f4421412d3270c25f54.jpg],origin[dam],category[],type[LOOKBOOK],res[m],hmver[1]&amp;call=url[file:/product/style]"/>
#  <div class="item-buttons">
#  <button class="favorite icon-favorites js-favorite" data-not-saved-text="SAVE AS FAVORITE" data-saved-text="SAVED AS FAVORITE" data-tracking-json-template="utagFavorite" data-tracking-params="Favourites|0985159002|Skinny Jeans|MEN_SHOPBYPRODUCT : JEANS_JEANS : VIEWALL_VIEW_ALL" data-tracking-type="event">
#  				SAVE AS FAVORITE</button>
#  </div></a>
#  </div><div class="item-details">
#  <div class="marketing-marker marker-environment" style="">
#  		Conscious </div>
#  <h3 class="item-heading">
#  <a class="link" href="/en_us/productpage.0985159002.html">Skinny Jeans</a>
#  </h3><strong class="item-price">
#  <span class="price regular">$ 19.99</span>
#  </strong><ul class="list-swatches" data-swatches-total="5">
#  <li class="item"><a class="swatch" href="/en_us/productpage.0985159002.html" style="background-color: #6089C2" title="Denim blue">
#  				Denim blue</a></li>
#  <li class="item"><a class="swatch" href="/en_us/productpage.0985159001.html" style="background-color: #272628" title="Black">
#  				Black</a></li>
#  <li class="item"><a class="swatch" href="/en_us/productpage.0985159003.html" style="background-color: #666B75" title="Dark gray">
#  				Dark gray</a></li>
#  <li class="item"><a class="swatch" href="/en_us/productpage.0985159004.html" style="background-color: #8898AC" title="Light denim blue">
#  				Light denim blue</a></li>
#  </ul></div></article>,
#  <article class="hm-product-item" data-articlecode="0868115006" data-category="men_jeans_skinny" data-energy-interval="" data-pre-access-end-date="" data-pre-access-groups="" data-pre-access-start-date="" onclick="setOsaParameters(utag_data.category_id,'SMALL','0868115006'); setNotificationTicket('Oy9wbHAvcHJvZHVjdC1saXN0LXdpdGgtY291bnQvcHJvZHVjdC1saXN0OyM7cHJvZHVjdF9rZXk7MDg2ODExNV9ncm91cF8wMDZfZW5fdXM7MDg2ODExNTAwNl9lbl91cztPQkpFQ1RJVkUkO05PTkU6Tk9ORTs3NTs','0868115006');">
#  <div class="image-container">
#  <a class="item-link" href="/en_us/productpage.0868115006.html" title="Skinny Cropped Jeans">
#  <img alt="Skinny Cropped JeansModel" class="item-image" data-altimage="//lp2.hm.com/hmgoepprod?set=source[/63/67/63674d516b58ebd7b60b8ab3ac7d12caf7d07bd5.jpg],origin[dam],category[men_jeans_skinny],type[DESCRIPTIVESTILLLIFE],res[m],hmver[2]&amp;call=url[file:/product/style]" data-alttext="Skinny Cropped Jeans" data-src="//lp2.hm.com/hmgoepprod?set=source[/f7/34/f7342109900089430d2c836f79870b2b2d3f8cf8.jpg],origin[dam],category[men_jeans_skinny],type[LOOKBOOK],res[m],hmver[1]&amp;call=url[file:/product/style]"/>
#  <div class="item-buttons">
#  <button class="favorite icon-favorites js-favorite" data-not-saved-text="SAVE AS FAVORITE" data-saved-text="SAVED AS FAVORITE" data-tracking-json-template="utagFavorite" data-tracking-params="Favourites|0868115006|Skinny Cropped Jeans|MEN_SHOPBYPRODUCT : JEANS_JEANS : VIEWALL_VIEW_ALL" data-tracking-type="event">
#  				SAVE AS FAVORITE</button>
#  </div></a>
#  </div><div class="item-details">
#  <h3 class="item-heading">
#  <a class="link" href="/en_us/productpage.0868115006.html">Skinny Cropped Jeans</a>
#  </h3><strong class="item-price">
#  <span class="price regular">$ 29.99</span>
#  </strong><ul class="list-swatches" data-swatches-total="4">
#  <li class="item"><a class="swatch" href="/en_us/productpage.0868115006.html" style="background-color: #FFFFFF" title="White">
#  				White</a></li>
#  <li class="item"><a class="swatch" href="/en_us/productpage.0868115001.html" style="background-color: #2E2E30" title="Black">
#  				Black</a></li>
#  <li class="item"><a class="swatch" href="/en_us/productpage.0868115005.html" style="background-color: #ADBAD1" title="Light denim blue">
#  				Light denim blue</a></li>
#  <li class="item"><a class="swatch" href="/en_us/productpage.0868115007.html" style="background-color: #C4CAD7" title="Light blue">
#  				Light blue</a></li>
#  </ul></div></article>]

# %%
# product_id

product_id = [p.get('data-articlecode') for p in product_list]

# product_category

product_category = [p.get('data-category') for p in product_list]

# %%
# product_name

product_list = products.find_all('a', class_='link')

product_name = [p.get_text() for p in product_list]

# %%
# price

product_list = products.find_all('span', class_='price regular')

product_price = [p.get_text() for p in product_list]

# %%
data = pd.DataFrame([product_id, product_category, product_name, product_price]).T

# %%
data.columns = ['product_id', 'product_category', 'product_name', 'product_price']

# scrapy datetime

data['scrapy_datetime'] = datetime.now().strftime('%Y-%m-%d %H:%M:%S')

# %%
data
# Out:
#     product_id   product_category                product_name product_price  \
# 0   0985159001   men_jeans_skinny                Skinny Jeans       $ 19.99
# 1   0985197001     men_jeans_slim                  Slim Jeans       $ 19.99
# 2   0690449022   men_jeans_ripped                Skinny Jeans       $ 39.99
# 3   0985197002     men_jeans_slim                  Slim Jeans       $ 19.99
# 4   0985159003   men_jeans_skinny                Skinny Jeans       $ 19.99
# 5   0427159006   men_jeans_ripped        Trashed Skinny Jeans       $ 39.99
# 6   0985197003     men_jeans_slim                  Slim Jeans       $ 19.99
# 7   0971061001                     Slim Tapered Cropped Jeans       $ 29.99
# 8   1004199001                           Skinny Cropped Jeans       $ 29.99
# 9   0971061002                     Slim Tapered Cropped Jeans       $ 29.99
# 10  0985159006   men_jeans_skinny                Skinny Jeans       $ 19.99
# 11  0985197006     men_jeans_slim                  Slim Jeans       $ 19.99
# 12  0751994024     men_jeans_slim                  Slim Jeans       $ 29.99
# 13  0985159004   men_jeans_skinny                Skinny Jeans       $ 19.99
# 14  0811993021  men_jeans_regular               Regular Jeans       $ 29.99
# 15  1004199002                           Skinny Cropped Jeans       $ 29.99
# 16  0751994031     men_jeans_slim                  Slim Jeans       $ 29.99
# 17  1004476005                            Freefit® Slim Jeans       $ 49.99
# 18  1004476004                            Freefit® Slim Jeans       $ 49.99
# 19  0974202001                          Regular Denim Joggers       $ 29.99
# 20  1004476001                            Freefit® Slim Jeans       $ 49.99
# 21  0730863005                                   Skinny Jeans       $ 29.99
# 22  0811993003  men_jeans_regular               Regular Jeans       $ 29.99
# 23  0974202003                          Regular Denim Joggers       $ 29.99
# 24  0974202002                          Regular Denim Joggers       $ 29.99
# 25  0811993024  men_jeans_regular               Regular Jeans       $ 29.99
# 26  0875105001  men_jeans_relaxed               Relaxed Jeans       $ 29.99
# 27  0875105003  men_jeans_relaxed               Relaxed Jeans       $ 29.99
# 28  0998599001                                  Regular Jeans       $ 24.99
# 29  0636207006                                     Slim Jeans       $ 19.99
# 30  0636207010                                     Slim Jeans       $ 19.99
# 31  0720504001   men_jeans_skinny                Skinny Jeans       $ 24.99
# 32  0720504008   men_jeans_skinny                Skinny Jeans       $ 24.99
# 33  0868115001   men_jeans_skinny        Skinny Cropped Jeans       $ 29.99
# 34  0985159002   men_jeans_skinny                Skinny Jeans       $ 19.99
# 35  0868115006   men_jeans_skinny        Skinny Cropped Jeans       $ 29.99
#
#         scrapy_datetime
# 0   2021-07-11 12:14:42
# 1   2021-07-11 12:14:42
# 2   2021-07-11 12:14:42
# 3   2021-07-11 12:14:42
# 4   2021-07-11 12:14:42
# 5   2021-07-11 12:14:42
# 6   2021-07-11 12:14:42
# 7   2021-07-11 12:14:42
# 8   2021-07-11 12:14:42
# 9   2021-07-11 12:14:42
# 10  2021-07-11 12:14:42
# 11  2021-07-11 12:14:42
# 12  2021-07-11 12:14:42
# 13  2021-07-11 12:14:42
# 14  2021-07-11 12:14:42
# 15  2021-07-11 12:14:42
# 16  2021-07-11 12:14:42
# 17  2021-07-11 12:14:42
# 18  2021-07-11 12:14:42
# 19  2021-07-11 12:14:42
# 20  2021-07-11 12:14:42
# 21  2021-07-11 12:14:42
# 22  2021-07-11 12:14:42
# 23  2021-07-11 12:14:42
# 24  2021-07-11 12:14:42
# 25  2021-07-11 12:14:42
# 26  2021-07-11 12:14:42
# 27  2021-07-11 12:14:42
# 28  2021-07-11 12:14:42
# 29  2021-07-11 12:14:42
# 30  2021-07-11 12:14:42
# 31  2021-07-11 12:14:42
# 32  2021-07-11 12:14:42
# 33  2021-07-11 12:14:42
# 34  2021-07-11 12:14:42
# 35  2021-07-11 12:14:42

# %% [markdown]
# # Coletando os Dados II

# %%
url = 'https://www2.hm.com/en_us/men/products/jeans.html'

headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/50.0.2661.102 Safari/537.36'}

page = requests.get(url, headers=headers)

# %%
soup = BeautifulSoup(page.text, 'html.parser')

# %%
# identificando o numero total de produtos

total_item = soup.find_all('h2', class_='load-more-heading')[0].get('data-total')

# %%
# transformando em inteiro

page_number = np.round(int(total_item) / 36)
page_number
# Out:
# 2.0

# %%
url02 = url + '?page-size=' + str(int(page_number*36))
url02
# Out:
# 'https://www2.hm.com/en_us/men/products/jeans.html?page-size=72'

# %%
int(total_item) / 36
# Out:
# 2.0555555555555554

# %% [markdown]
# # Coletando os dados III

# %% [markdown]
# ## Um produto

# %%
# API requests

url = 'https://www2.hm.com/en_us/productpage.0636207019.html'

headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/50.0.2661.102 Safari/537.36'}

page = requests.get(url, headers=headers)

# beautiful soup object

soup = BeautifulSoup(page.text, 'html.parser')

# %%
# ================================ color name ================================

product_list = soup.find_all('a', class_='filter-option miniature')

color_name = [p.get('data-color') for p in product_list]

# product id

product_id = [p.get('data-articlecode') for p in product_list]

df_color = pd.DataFrame([product_id, color_name]).T
df_color.columns = ['product_id', 'color_name']

# novas colunas de 'style_id' com os 7 primeiros digitos, e 'color_id' com os 3 últimos digitos

df_color['style_id'] = df_color['product_id'].apply(lambda x: x[:-3])
df_color['color_id'] = df_color['product_id'].apply(lambda x: x[-3:])

# %%
# =============================== composition ================================


product_composition_list = soup.find_all('div', class_='pdp-description-list-item')

product_composition = [list(filter(None, p.get_text().split('\n'))) for p in product_composition_list]


# transformando em dataframe

df_composition = pd.DataFrame(product_composition).T


# primeira linha como cabeçalho

df_composition.columns = df_composition.iloc[0]

# deletando a primeira linha do df

df_composition = df_composition.iloc[1:].fillna(method='ffill')

# novas colunas de 'style_id' com os 7 primeiros digitos, e 'color_id' com os 3 últimos digitos

df_composition['style_id'] = df_composition['Art. No.'].apply(lambda x: x[:-3])
df_composition['color_id'] = df_composition['Art. No.'].apply(lambda x: x[-3:])

# %%
# ============================== unindo os dados ===============================

# join color e composition

data_sku = pd.merge(df_color, df_composition[['style_id','Fit','Composition']], how='left', on='style_id')

# %% [markdown]
# ## Múltiplos produtos

# %%
headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/50.0.2661.102 Safari/537.36'}


# dataframe vazio

df_details = pd.DataFrame()

# colunas únicas para todos os produtos

aux = []

cols = ['Art. No.', 'Composition', 'Fit', 'Product safety','Size']
df_pattern = pd.DataFrame(columns= cols)

# %%
for i in range(len(data)):

    # API requests

    url = 'https://www2.hm.com/en_us/productpage.' + data.loc[i, 'product_id'] + '.html'

    page = requests.get(url, headers=headers)

    # beautiful soup object

    soup = BeautifulSoup(page.text, 'html.parser')
    

    # ================================ color name ================================

    product_list = soup.find_all('a', class_='filter-option miniature')

    color_name = [p.get('data-color') for p in product_list]

    # product id

    product_id = [p.get('data-articlecode') for p in product_list]

    df_color = pd.DataFrame([product_id, color_name]).T
    df_color.columns = ['product_id', 'color_name']

    # novas colunas de 'style_id' com os 7 primeiros digitos, e 'color_id' com os 3 últimos digitos

    df_color['style_id'] = df_color['product_id'].apply(lambda x: x[:-3])
    df_color['color_id'] = df_color['product_id'].apply(lambda x: x[-3:])


    # =============================== composition ================================


    product_composition_list = soup.find_all('div', class_='pdp-description-list-item')

    product_composition = [list(filter(None, p.get_text().split('\n'))) for p in product_composition_list]


    # transformando em dataframe

    df_composition = pd.DataFrame(product_composition).T


    # primeira linha como cabeçalho

    df_composition.columns = df_composition.iloc[0]

    # deletando a primeira linha do df

    df_composition = df_composition.iloc[1:].fillna(method='ffill')
    
    # garantindo o mesmo número de colunas
    
    df_composition = pd.concat([df_pattern, df_composition], axis=0)

    # novas colunas de 'style_id' com os 7 primeiros digitos, e 'color_id' com os 3 últimos digitos

    df_composition['style_id'] = df_composition['Art. No.'].apply(lambda x: x[:-3])
    df_composition['color_id'] = df_composition['Art. No.'].apply(lambda x: x[-3:])
    
    aux = aux + df_composition.columns.tolist()


    # ============================== unindo os dados ===============================

    # join color e composition

    data_sku = pd.merge(df_color, df_composition[['style_id','Fit','Size', 'Product safety','Composition']], how='left', on='style_id')
    
    df_details = pd.concat([df_details, data_sku], axis=0)

# %%
# join vitrine e details

data['style_id'] = data['product_id'].apply(lambda x: x[:-3])
data['color_id'] = data['product_id'].apply(lambda x: x[-3:])

data_raw = pd.merge(data, df_details[['style_id', 'color_name', 'Fit', 'Composition', 'Size', 'Product safety']],
                    how='left', on='style_id')

# %%
data_raw.head()
# Out:
#    product_id  product_category  product_name product_price  \
# 0  0985159001  men_jeans_skinny  Skinny Jeans       $ 19.99
# 1  0985159001  men_jeans_skinny  Skinny Jeans       $ 19.99
# 2  0985159001  men_jeans_skinny  Skinny Jeans       $ 19.99
# 3  0985159001  men_jeans_skinny  Skinny Jeans       $ 19.99
# 4  0985159001  men_jeans_skinny  Skinny Jeans       $ 19.99
#
#        scrapy_datetime style_id color_id        color_name         Fit  \
# 0  2021-07-11 12:14:42  0985159      001        Denim blue  Skinny fit
# 1  2021-07-11 12:14:42  0985159      001        Denim blue  Skinny fit
# 2  2021-07-11 12:14:42  0985159      001         Dark gray  Skinny fit
# 3  2021-07-11 12:14:42  0985159      001         Dark gray  Skinny fit
# 4  2021-07-11 12:14:42  0985159      001  Light denim blue  Skinny fit
#
#                       Composition  \
# 0  Shell: Cotton 99%, Elastane 1%
# 1      Pocket lining: Cotton 100%
# 2  Shell: Cotton 99%, Elastane 1%
# 3      Pocket lining: Cotton 100%
# 4  Shell: Cotton 99%, Elastane 1%
#
#                                              Size Product safety
# 0  The model is 187cm/6'2" and wears a size 31/32            NaN
# 1  The model is 187cm/6'2" and wears a size 31/32            NaN
# 2  The model is 187cm/6'2" and wears a size 31/32            NaN
# 3  The model is 187cm/6'2" and wears a size 31/32            NaN
# 4  The model is 187cm/6'2" and wears a size 31/32            NaN

# %%
# salvando o df

data_raw.to_csv('products_hm.csv',index_label=False)

# %% [markdown]
# ## Tratamento de dados

# %%
data = pd.read_csv('products_hm.csv')

# %%
data[['Composition','product_id']].groupby('Composition').count().reset_index()
# Out:
#                                  Composition  product_id
# 0                                Cotton 100%          26
# 1     Cotton 73%, Polyester 26%, Elastane 1%          30
# 2     Cotton 80%, Polyester 19%, Elastane 1%          18
# 3     Cotton 88%, Polyester 10%, Elastane 2%          20
# 4   Cotton 90%, Elasterell-P 8%, Elastane 2%          18
# 5      Cotton 93%, Polyester 6%, Elastane 1%          14
# 6                    Cotton 98%, Elastane 2%         193
# 7                    Cotton 99%, Elastane 1%          52
# 8                     Lining: Polyester 100%          15
# 9                 Pocket lining: Cotton 100%         156
# 10             Pocket lining: Polyester 100%          18
# 11  Pocket lining: Polyester 63%, Cotton 37%          20
# 12  Pocket lining: Polyester 65%, Cotton 35%          56
# 13            Shell: Cotton 98%, Elastane 2%          13
# 14            Shell: Cotton 99%, Elastane 1%         181

# %%
data.head()
# Out:
#    product_id  product_category  product_name product_price  \
# 0   985159001  men_jeans_skinny  Skinny Jeans       $ 19.99
# 1   985159001  men_jeans_skinny  Skinny Jeans       $ 19.99
# 2   985159001  men_jeans_skinny  Skinny Jeans       $ 19.99
# 3   985159001  men_jeans_skinny  Skinny Jeans       $ 19.99
# 4   985159001  men_jeans_skinny  Skinny Jeans       $ 19.99
#
#        scrapy_datetime  style_id  color_id        color_name         Fit  \
# 0  2021-07-11 12:14:42    985159         1        Denim blue  Skinny fit
# 1  2021-07-11 12:14:42    985159         1        Denim blue  Skinny fit
# 2  2021-07-11 12:14:42    985159         1         Dark gray  Skinny fit
# 3  2021-07-11 12:14:42    985159         1         Dark gray  Skinny fit
# 4  2021-07-11 12:14:42    985159         1  Light denim blue  Skinny fit
#
#                       Composition  \
# 0  Shell: Cotton 99%, Elastane 1%
# 1      Pocket lining: Cotton 100%
# 2  Shell: Cotton 99%, Elastane 1%
# 3      Pocket lining: Cotton 100%
# 4  Shell: Cotton 99%, Elastane 1%
#
#                                              Size Product safety
# 0  The model is 187cm/6'2" and wears a size 31/32            NaN
# 1  The model is 187cm/6'2" and wears a size 31/32            NaN
# 2  The model is 187cm/6'2" and wears a size 31/32            NaN
# 3  The model is 187cm/6'2" and wears a size 31/32            NaN
# 4  The model is 187cm/6'2" and wears a size 31/32            NaN

# %%
data.isna().sum()
# Out:
# product_id            0
# product_category    124
# product_name          0
# product_price         0
# scrapy_datetime       0
# style_id              0
# color_id              0
# color_name            0
# Fit                   0
# Composition           0
# Size                456
# Product safety      632
# dtype: int64

# %%
data = pd.read_csv('products_hm.csv')


# product id


data['product_id'] = data['product_id'].astype(int)

# product name

data['product_name'] = data['product_name'].apply(lambda x: x.replace(' ', '_').lower() )


# product price

data['product_price'] = data['product_price'].apply(lambda x: x.replace('$ ', '') if pd.notnull(x) else x )

# scrapy datetime

data['scrapy_datetime'] = pd.to_datetime(data['scrapy_datetime'], format='%Y-%m-%d %H:%M:%S')

# style id

data['style_id'] = data['style_id'].astype(int)

# color id

data['color_id'] = data['color_id'].astype(int)

# color name

data['color_name'] = data['color_name'].apply(lambda x: x.replace(' ', '_').replace('/', '_').lower() if pd.notnull(x) else x )

# fit

data['Fit'] = data['Fit'].apply(lambda x: x.replace(' ', '_').lower() if pd.notnull(x) else x )

# size model

data['size_model'] = data['Size'].apply(lambda x: re.search('\d{3}cm', x).group(0) if pd.notnull(x) else x )
data['size_model'] = data['size_model'].apply(lambda x: re.search('\d+', x).group(0) if pd.notnull(x) else x )

# size number

data['size_number'] = data['Size'].str.extract('(\d+/\\d+)')



# product safety

# composition

#data['Composition'] = data['Composition'].apply(lambda x: x.replace('Pocket lining: ', '').replace('Lining: ', '').replace('Shell: ', ''))

data = data[~data['Composition'].str.contains('Pocket lining:', na=False)] # removendo a composição do forro do bolso
data = data[~data['Composition'].str.contains('Lining:', na=False)]
data = data[~data['Composition'].str.contains('Shell:', na=False)]

# drop duplicate

data = data.drop_duplicates(subset=['product_id','product_category','product_name', 'product_price',
                                   'scrapy_datetime', 'style_id', 'color_id', 'color_name','Fit'], keep='last')


# reset index

data = data.reset_index(drop=True)

# breack composition by comma

df1 = data['Composition'].str.split(',', expand=True)

# %%
data['Composition'].unique()
# Out:
# array(['Cotton 98%, Elastane 2%', 'Cotton 93%, Polyester 6%, Elastane 1%',
#        'Cotton 99%, Elastane 1%',
#        'Cotton 90%, Elasterell-P 8%, Elastane 2%', 'Cotton 100%',
#        'Cotton 88%, Polyester 10%, Elastane 2%',
#        'Cotton 80%, Polyester 19%, Elastane 1%',
#        'Cotton 73%, Polyester 26%, Elastane 1%'], dtype=object)

# %%
# cotton / polyester / elastano / elasterell

df_ref = pd.DataFrame( index=np.arange(len(data)), columns=['cotton', 'polyester', 'elastano', 'elasterell'])

###################################

# cotton

df_cotton = df1.loc[df1[0].str.contains('Cotton', na=True),0] # selecionando os 'cotton' da primeira coluna
df_cotton.name = 'cotton1'

df_ref = pd.concat([df_ref, df_cotton], axis=1) # concatenando com o df de referencia
df_ref = df_ref.iloc[:, ~df_ref.columns.duplicated(keep='last')]

df_cotton = df1.loc[df1[1].str.contains('Cotton', na=True),1] # selecionando os 'cotton' da segunda coluna
df_cotton.name = 'cotton2'

df_ref = pd.concat([df_ref, df_cotton], axis=1) # concatenando com o df de referencia
df_ref = df_ref.iloc[:, ~df_ref.columns.duplicated(keep='last')]

df_ref['cotton1'] = df_ref['cotton1'].fillna(df_ref['cotton2']) # juntando os 'cotton' em uma coluna
df_ref['cotton1'] = df_ref['cotton1'].fillna('Cotton 0%')

df_ref.drop(columns=['cotton2'], inplace=True) # excluindo a coluna cotton2

###################################

# polyester

df_polyester = df1.loc[df1[0].str.contains('Polyester', na=True),0] # selecionando os 'polyester' da primeira coluna
df_polyester.name = 'polyester1'

df_ref = pd.concat([df_ref, df_polyester], axis=1) # concatenando com o df de referencia
df_ref = df_ref.iloc[:, ~df_ref.columns.duplicated(keep='last')]

df_polyester = df1.loc[df1[1].str.contains('Polyester', na=True),1] # selecionando os 'polyester' da segunda coluna
df_polyester.name = 'polyester2'

df_ref = pd.concat([df_ref, df_polyester], axis=1) # concatenando com o df de referencia
df_ref = df_ref.iloc[:, ~df_ref.columns.duplicated(keep='last')]

df_ref['polyester1'] = df_ref['polyester1'].fillna(df_ref['polyester2']) # juntando os 'polyester' em uma coluna
df_ref['polyester1'] = df_ref['polyester1'].fillna('Polyester 0%')

df_ref.drop(columns=['polyester2'], inplace=True) # excluindo a coluna polyester2

###################################

# elastano

df_elastane = df1.loc[df1[1].str.contains('Elastane', na=True),1] # selecionando os 'elastane' da segunda coluna
df_elastane.name = 'elastane1'

df_ref = pd.concat([df_ref, df_elastane], axis=1) # concatenando com o df de referencia
df_ref = df_ref.iloc[:, ~df_ref.columns.duplicated(keep='last')]

df_elastane = df1.loc[df1[2].str.contains('Elastane', na=True),2] # selecionando os 'elastane' da terceira coluna
df_elastane.name = 'elastane2'

df_ref = pd.concat([df_ref, df_elastane], axis=1) # concatenando com o df de referencia
df_ref = df_ref.iloc[:, ~df_ref.columns.duplicated(keep='last')]

df_ref['elastane1'] = df_ref['elastane1'].fillna(df_ref['elastane2']) # juntando os 'elastane' em uma coluna
df_ref['elastane1'] = df_ref['elastane1'].fillna('Elastane 0%')

df_ref.drop(columns=['elastane2'], inplace=True) # excluindo a coluna elastane2


###################################

# elasterell

df_elasterell = df1.loc[df1[1].str.contains('Elasterell', na=True),1] # selecionando os 'elasterell' da segunda coluna
df_elasterell.name = 'elasterell'

df_ref = pd.concat([df_ref, df_elasterell], axis=1) # concatenando com o df de referencia

df_ref = df_ref.iloc[:, ~df_ref.columns.duplicated(keep='last')] # mantendo a últina coluna elasterell

df_ref['elasterell'] = df_ref['elasterell'].fillna('Elasterell 0%')

# %%
df_ref
# Out:
#     cotton polyester elastano     cotton1      polyester1     elastane1  \
# 0      NaN       NaN      NaN  Cotton 98%    Polyester 0%   Elastane 2%
# 1      NaN       NaN      NaN  Cotton 98%    Polyester 0%   Elastane 2%
# 2      NaN       NaN      NaN  Cotton 98%    Polyester 0%   Elastane 2%
# 3      NaN       NaN      NaN  Cotton 98%    Polyester 0%   Elastane 2%
# 4      NaN       NaN      NaN  Cotton 98%    Polyester 0%   Elastane 2%
# ..     ...       ...      ...         ...             ...           ...
# 158    NaN       NaN      NaN  Cotton 73%   Polyester 26%   Elastane 1%
# 159    NaN       NaN      NaN  Cotton 73%   Polyester 26%   Elastane 1%
# 160    NaN       NaN      NaN  Cotton 73%   Polyester 26%   Elastane 1%
# 161    NaN       NaN      NaN  Cotton 73%   Polyester 26%   Elastane 1%
# 162    NaN       NaN      NaN  Cotton 73%   Polyester 26%   Elastane 1%
#
#         elasterell
# 0    Elasterell 0%
# 1    Elasterell 0%
# 2    Elasterell 0%
# 3    Elasterell 0%
# 4    Elasterell 0%
# ..             ...
# 158  Elasterell 0%
# 159  Elasterell 0%
# 160  Elasterell 0%
# 161  Elasterell 0%
# 162  Elasterell 0%
#
# [163 rows x 7 columns]

# %%
# excluindo as colunas referenciais

df_ref.drop(columns=['cotton', 'polyester', 'elastano'], inplace=True)

df_ref = df_ref.rename(columns={'cotton1': 'cotton', 'polyester1':'polyester', 'elastane1': 'elastane'})

df_ref= df_ref.fillna(value=np.nan)

# %%
df_ref.head()
# Out:
#        cotton     polyester      elastane     elasterell
# 0  Cotton 98%  Polyester 0%   Elastane 2%  Elasterell 0%
# 1  Cotton 98%  Polyester 0%   Elastane 2%  Elasterell 0%
# 2  Cotton 98%  Polyester 0%   Elastane 2%  Elasterell 0%
# 3  Cotton 98%  Polyester 0%   Elastane 2%  Elasterell 0%
# 4  Cotton 98%  Polyester 0%   Elastane 2%  Elasterell 0%

# %%
# final join

data = pd.concat([data, df_ref], axis=1)

# format composition data

data['cotton'] = data['cotton'].apply(lambda x: int(re.search('\d+', x).group(0)) / 100 if pd.notnull(x) else x)
data['polyester'] = data['polyester'].apply(lambda x: int(re.search('\d+', x).group(0)) / 100 if pd.notnull(x) else x)
data['elastane'] = data['elastane'].apply(lambda x: int(re.search('\d+', x).group(0)) / 100 if pd.notnull(x) else x)
data['elasterell'] = data['elasterell'].apply(lambda x: int(re.search('\d+', x).group(0)) / 100 if pd.notnull(x) else x)


# drop columns

data = data.drop(columns=['Size', 'Product safety','Composition'], axis=1)

# drop duplicates

data = data.drop_duplicates()

data.to_csv('products_hm_cleaned.csv', index_label=False)
